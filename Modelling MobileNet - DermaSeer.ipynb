# %% [markdown]
# # Capstone Project - DermaSeer

# %% [markdown]
# After performing the dataset processing stage, the next step is the modeling process. Where the data used to build the model is training data stored in the normalization-train folder, validation data stored in the normalization-validation folder, and testing data stored in the test folder.

# %% [markdown]
# # 1. Import Library

# %%
import os # handles operating system-related tasks like file and directory operations
import shutil # provides functions to copy, move, and delete files or directories
from collections import defaultdict # creates dictionaries with default values
from tensorflow.keras import layers, models # defines neural network layers for deep learning models, constructs and manages neural network models
from tensorflow.keras.optimizers import RMSprop # applies the rmsprop optimization algorithm for training
from tensorflow.keras.callbacks import LearningRateScheduler # dynamically adjusts the learning rate during training
from tensorflow.keras import regularizers # adds regularization to model layers to reduce overfitting
from tensorflow.keras.preprocessing.image import ImageDataGenerator # generates batches of tensor image data with real-time data augmentation
import matplotlib.pyplot as plt # visualizes data with plots, graphs, and chart
from tensorflow.keras.applications import InceptionV3 # imports the pre-trained InceptionV3 model for image classification tasks, enabling transfer learning or feature extraction
import numpy as np # used for array manipulation and numerical operations
from tensorflow.keras.preprocessing import image # provides functions to load, preprocess, and convert images into the appropriate format for deep learning models
import ipywidgets as widgets # provides interactive widgets 
from IPython.display import display, Image, clear_output # allows displaying images and outputs
from tensorflow.keras.models import load_model # loads a pre-trained model from a file

# %% [markdown]
# # 2. Fireplace Folder Dataset

# %% [markdown]
# At this stage, copies folders from "normalization-images" (e.g., normalization-train, normalization-validation) to new folders (data-train, data-validation) using shutil.copytree(). It also consolidates files from subfolders in the "test" folder into a single "data-test" folder for easier data access during modeling.

# %% [markdown]
# Befotre:
# <pre>
# normalization-images/
# ├── normalization-train/
# │   ├── file1.jpg
# │   ├── file2.jpg
# │   └── ...
# ├── normalization-validation/
# │   ├── file3.jpg
# │   ├── file4.jpg
# │   └── ...
# test/
# ├── subfolder1/
# │   ├── file5.jpg
# │   ├── file6.jpg
# │   └── ...
# ├── subfolder2/
# │   ├── file7.jpg
# │   ├── file8.jpg
# │   └── ...
# </pre>
#
# After:
# <pre>
# current_directory/
# ├── data-train/
# │   ├── file1.jpg
# │   ├── file2.jpg
# │   └── ...
# ├── data-validation/
# │   ├── file3.jpg
# │   ├── file4.jpg
# │   └── ...
# ├── data-test/
# │   ├── file5.jpg
# │   ├── file6.jpg
# │   ├── file7.jpg
# │   ├── file8.jpg
# │   └── ...
# </pre>

# %%
# specify source folder path and destination
source_folder = 'normalization-images'  # source folder
destination = '.'  # destination directory (current directory)

# folders to copy and their corresponding destination names
folders_to_copy = {
    'normalization-train': 'data-train', 
    'normalization-validation': 'data-validation'
}

# copy each folder
for source_folder_name, dest_folder_name in folders_to_copy.items():
    source_path = os.path.join(source_folder, source_folder_name)
    destination_path = os.path.join(destination, dest_folder_name)
    
    # copy the folder
    if os.path.exists(source_path):
        shutil.copytree(source_path, destination_path)
        print(f"Folder {source_folder_name} Has Been Copied To {destination_path}")
    else:
        print(f"Folder {source_folder_name} Not Found In {source_folder}")
# Out:
# Folder normalization-train Has Been Copied To ./data-train
# Folder normalization-validation Has Been Copied To ./data-validation

# %%
# specify the source and destination folders
source_folder = 'test'  # the folder containing subfolders
destination = 'data-test'  # the folder where data should be copied

# create the destination folder if it doesn't exist
if not os.path.exists(destination):
    os.makedirs(destination)

# loop through all subfolders in the source folder
for subfolder in os.listdir(source_folder):
    subfolder_path = os.path.join(source_folder, subfolder)
    
    # check if it's a folder
    if os.path.isdir(subfolder_path):
        # loop through all files in the subfolder
        for file in os.listdir(subfolder_path):
            file_path = os.path.join(subfolder_path, file)
            
            # check if it's a file and copy it to the destination folder
            if os.path.isfile(file_path):
                destination_path = os.path.join(destination, file)
                shutil.copy(file_path, destination_path)

# print 'All Completed' after all files have been processed
print("All Completed")
# Out:
# All Completed

# %% [markdown]
# # 3. Labelling Dataset

# %% [markdown]
# At this stage, processes image data stored in data-train, data-validation, and data-test folders by categorizing images based on labels in their filenames. It groups images by label into a dictionary and moves each image to the corresponding label subfolder. If a label subfolder doesn't exist, it is created.

# %%
# specify dataset folders (folders are in the same directory as the script)
folders = ['data-train', 'data-validation', 'data-test']

# dictionary to store images by class
class_dict = defaultdict(list)

# process each dataset folder
for folder in folders:
    # path directly to the folder that is in the same directory as the script
    folder_path = folder  # since the folder is already in the same directory, just use the folder name directly
    
    # process each image in the folder
    for image in os.listdir(folder_path):
        if image.endswith(('.jpg', '.JPG', '.png', '.jfif')):  # only process image files
            # get the text after the last underscore
            label_part = image.split('_')[-1]
            
            # check if the second character is a digit, if so, take only the first character
            if len(label_part) > 1 and label_part[1].isdigit():
                label = label_part[0]  # only take the first character
            else:
                label = label_part[:2]  # take the first two characters if both are letters
            
            # store the image in the dictionary by label and folder
            class_dict[label].append(os.path.join(folder, image))

# generate the class_dict to check the labeling result
# print the dictionary to see the images by label
for label, images in class_dict.items():
    print(f"Label: {label}")
    print(f"Number of images: {len(images)}")
    print("Image paths:")
    for img in images:
        print(f"  - {img}")
    print("-" * 50)
# Out:
# Label: f
# Number of images: 318
# Image paths:
#   - data-train/Normalized_Augmented_3_resized_f48.JPG
#   - data-train/Normalized_Augmented_4_resized_f70.JPG
#   - data-train/Normalized_Augmented_4_resized_f64.JPG
#   - data-train/Normalized_Augmented_3_resized_f60.JPG
#   - data-train/Normalized_Augmented_4_resized_f58.JPG
#   - data-train/Normalized_Augmented_0_resized_f19.JPG
#   - data-train/Normalized_Augmented_2_resized_f39.JPG
#   - data-train/Normalized_Augmented_2_resized_f7.JPG
#   - data-train/Normalized_Augmented_1_resized_f40.JPG
#   - data-train/Normalized_Augmented_1_resized_f68.JPG
#   - data-train/Normalized_Augmented_1_resized_f55.JPG
#   - data-train/Normalized_Augmented_1_resized_f41.JPG
#   - data-train/Normalized_Augmented_2_resized_f10.JPG
#   - data-train/Normalized_Augmented_2_resized_f38.JPG
#   - data-train/Normalized_Augmented_0_resized_f24.JPG
#   - data-train/Normalized_Augmented_0_resized_f30.JPG
#   - data-train/Normalized_Augmented_4_resized_f1.JPG
#   - data-train/Normalized_Augmented_3_resized_f61.JPG
#   - data-train/Normalized_Augmented_4_resized_f65.JPG
#   - data-train/Normalized_Augmented_0_resized_f26.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu3.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu35.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu49.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu61.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu60.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu48.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu16.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu56.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu35.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu3.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu11.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu38.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu10.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu32.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu2.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu36.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu55.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu41.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu15.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu36.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu56.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu48.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu60.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu3.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu16.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu2.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu61.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu49.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu35.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu56.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu32.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu10.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu38.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu11.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu55.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu41.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu16.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu48.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu60.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu56.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu35.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu61.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu49.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu2.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu15.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu41.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu55.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu36.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu3.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu10.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu38.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu32.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu11.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu61.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu49.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu48.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu60.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu49.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu61.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu35.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu56.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu16.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu60.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu48.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu38.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu10.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu36.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu55.JPG
#   - data-validation/Normalized_Augmented_2_resized_fu41.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu15.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu11.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu15.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu11.JPG
#   - data-validation/Normalized_Augmented_3_resized_fu32.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu38.JPG
#   - data-validation/Normalized_Augmented_0_resized_fu10.JPG
#   - data-validation/Normalized_Augmented_4_resized_fu16.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu2.JPG
#   - data-validation/Normalized_Augmented_1_resized_fu3.JPG
#   - data-test/fu63.JPG
#   - data-test/fu64.JPG
#   - data-test/fu8.JPG
#   - data-test/fu29.JPG
#   - data-test/fu17.JPG
#   - data-test/fu30.JPG
#   - data-test/fu1.jpg
#   - data-test/fu52.JPG
# --------------------------------------------------

# %%
# specify dataset folders (folders are in the same directory as the script)
folders = ['data-train', 'data-validation', 'data-test']

# dictionary to store images by class
class_dict = defaultdict(list)

# process each dataset folder
for folder in folders:
    folder_path = folder  # since the folder is already in the same directory, just use the folder name directly
    
    # process each image in the folder
    for image in os.listdir(folder_path):
        if image.endswith(('.jpg', '.JPG', '.png', '.jfif')):  # only process image files
            # get the text after the last underscore
            label_part = image.split('_')[-1]
            
            # check if the second character is a digit, if so, take only the first character
            if len(label_part) > 1 and label_part[1].isdigit():
                label = label_part[0]  # only take the first character
            else:
                label = label_part[:2]  # take the first two characters if both are letters
            
            # add the image to the class_dict
            class_dict[label].append(os.path.join(folder, image))

# now, move the images into their respective label folders
for label, images in class_dict.items():
    for folder in folders:
        # create label directory inside each folder if it doesn't exist
        label_folder_path = os.path.join(folder, label)
        if not os.path.exists(label_folder_path):
            os.makedirs(label_folder_path)

        # move each image to the corresponding label folder
        for image_path in images:
            # check if the image is in the current folder being processed
            if image_path.startswith(folder):
                # move the image to the label folder inside the dataset folder
                image_name = os.path.basename(image_path)
                destination_path = os.path.join(label_folder_path, image_name)
                shutil.move(image_path, destination_path)
                print(f"Moved {image_name} to {label_folder_path}")

# print to verify the labeling and the move operation
for folder in folders:
    print(f"\nContents of {folder}:")
    for label in os.listdir(folder):
        label_folder_path = os.path.join(folder, label)
        if os.path.isdir(label_folder_path):
            print(f"  {label}: {len(os.listdir(label_folder_path))} images")
# Out:
# Moved Normalized_Augmented_3_resized_f48.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f70.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f64.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f60.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f58.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f19.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f39.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f7.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f40.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f68.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f55.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f41.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f10.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f38.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f24.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f30.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f1.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f61.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f65.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f26.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f32.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f12.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f57.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f43.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f4.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f42.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f5.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f1.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f33.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f62.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f62.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f5.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f17.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f52.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f1.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f46.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f53.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f16.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f22.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f4.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f7.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f65.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f61.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f5.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f20.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f14.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f28.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f50.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f44.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f29.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f15.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f35.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f7.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f4.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f58.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f60.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f64.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f70.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f48.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f17.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f52.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f46.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f22.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f7.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f53.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f16.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f12.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f10.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f28.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f38.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f14.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f1.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f65.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f5.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f20.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f35.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f4.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f64.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f70.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f58.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f50.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f44.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f15.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f39.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f29.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f29.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f39.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f15.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f4.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f68.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f40.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f60.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f48.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f19.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f24.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f30.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f1.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f61.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f55.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f41.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f5.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f14.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f38.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f28.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f10.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f12.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f16.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f7.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f57.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f43.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f26.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f32.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f33.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f62.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f42.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f17.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f32.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f26.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f22.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f53.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f16.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f17.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f52.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f46.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f33.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f19.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f35.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f8.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f64.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f70.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f58.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f50.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f44.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f15.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f29.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f28.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f14.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f65.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f9.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f20.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f30.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f24.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f24.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f30.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f20.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f61.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f55.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f41.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f9.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f38.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f10.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f39.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f8.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f68.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f40.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f60.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f48.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f35.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f19.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f33.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f62.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f42.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f12.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f57.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f43.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f22.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f26.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f32.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f55.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f41.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f9.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f10.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f38.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f24.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f30.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f61.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f48.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f60.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f19.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f39.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f8.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f40.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f44.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f68.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f50.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f46.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f52.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f42.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f9.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f33.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f62.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f26.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f32.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f8.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f12.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f57.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f43.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f53.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f53.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f43.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f57.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f16.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f22.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f8.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f9.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f17.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f42.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f52.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f46.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f50.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f68.JPG to data-train/f
# Moved Normalized_Augmented_3_resized_f44.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f40.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f29.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f15.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f35.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f58.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f64.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f70.JPG to data-train/f
# Moved Normalized_Augmented_1_resized_f65.JPG to data-train/f
# Moved Normalized_Augmented_2_resized_f20.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f14.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f28.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f41.JPG to data-train/f
# Moved Normalized_Augmented_4_resized_f55.JPG to data-train/f
# Moved Normalized_Augmented_0_resized_f31.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f3.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f11.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f69.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f6.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f2.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f18.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f59.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f67.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f3.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f27.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f2.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f66.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f66.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f6.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f23.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f36.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f67.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f59.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f6.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f34.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f45.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f2.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f51.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f3.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f21.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f2.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f66.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f6.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f23.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f36.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f67.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f3.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f45.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f51.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f59.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f34.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f21.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f11.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f11.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f31.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f18.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f69.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f3.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f27.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f2.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f6.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f36.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f67.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f66.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f23.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f27.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f31.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f21.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f45.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f51.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f59.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f34.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f18.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f18.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f34.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f69.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f11.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f21.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f31.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f27.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f23.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f36.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f51.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f69.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f45.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f18.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f31.JPG to data-validation/f
# Moved Normalized_Augmented_0_resized_f11.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f27.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f36.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f67.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f66.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f23.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f21.JPG to data-validation/f
# Moved Normalized_Augmented_1_resized_f59.JPG to data-validation/f
# Moved Normalized_Augmented_2_resized_f34.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f45.JPG to data-validation/f
# Moved Normalized_Augmented_4_resized_f69.JPG to data-validation/f
# Moved Normalized_Augmented_3_resized_f51.JPG to data-validation/f
# Moved f56.JPG to data-test/f
# Moved f54.JPG to data-test/f
# Moved f47.JPG to data-test/f
# Moved f37.JPG to data-test/f
# Moved f25.JPG to data-test/f
# Moved f13.JPG to data-test/f
# Moved f63.JPG to data-test/f
# Moved f49.JPG to data-test/f
# Moved Normalized_Augmented_3_resized_pa57.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa43.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa17.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa3.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa65.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa59.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa64.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa16.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa34.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa42.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa56.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa40.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa68.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa36.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa14.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa28.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa8.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa66.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa67.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa1.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa63.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa29.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa9.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa15.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa37.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa55.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa41.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa39.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa11.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa67.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa5.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa63.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa66.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa10.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa38.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa50.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa44.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa52.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa46.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa18.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa30.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa64.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa6.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa7.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa65.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa59.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa13.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa25.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa31.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa19.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa53.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa34.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa5.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa56.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa42.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa16.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa9.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa13.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa8.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa17.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa43.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa57.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa37.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa6.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa41.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa55.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa63.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa15.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa29.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa11.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa39.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa38.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa10.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa28.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa14.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa68.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa40.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa7.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa36.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa3.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa44.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa50.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa66.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa38.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa10.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa28.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa14.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa15.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa29.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa11.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa39.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa67.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa19.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa31.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa25.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa53.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa59.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa65.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa13.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa8.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa17.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa16.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa9.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa64.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa46.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa52.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa30.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa18.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa1.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa15.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa29.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa63.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa55.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa41.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa37.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa1.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa5.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa36.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa68.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa40.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa28.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa14.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa16.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa42.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa56.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa34.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa7.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa3.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa30.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa18.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa19.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa25.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa31.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa6.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa57.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa43.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa17.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa13.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa59.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa65.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa53.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa19.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa25.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa31.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa6.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa34.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa3.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa7.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa30.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa18.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa52.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa46.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa64.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa38.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa9.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa10.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa66.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa50.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa44.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa5.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa1.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa36.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa37.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa67.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa8.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa11.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa39.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa14.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa28.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa36.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa40.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa68.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa44.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa50.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa41.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa55.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa3.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa37.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa29.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa15.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa63.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa17.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa1.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa43.jpg to data-train/pa
# Moved Normalized_Augmented_0_resized_pa57.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa9.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa53.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa46.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa52.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa8.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa56.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa42.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa34.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa16.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa64.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa18.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa30.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa46.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa52.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa56.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa42.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa43.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa57.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa53.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa31.JPG to data-train/pa
# Moved Normalized_Augmented_1_resized_pa25.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa5.jpg to data-train/pa
# Moved Normalized_Augmented_1_resized_pa19.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa13.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa65.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa59.JPG to data-train/pa
# Moved Normalized_Augmented_3_resized_pa67.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa39.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa11.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa7.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa41.jpg to data-train/pa
# Moved Normalized_Augmented_4_resized_pa55.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa40.JPG to data-train/pa
# Moved Normalized_Augmented_4_resized_pa68.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa44.JPG to data-train/pa
# Moved Normalized_Augmented_0_resized_pa50.jpg to data-train/pa
# Moved Normalized_Augmented_2_resized_pa6.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa10.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa38.jpg to data-train/pa
# Moved Normalized_Augmented_3_resized_pa66.JPG to data-train/pa
# Moved Normalized_Augmented_2_resized_pa35.jpg to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa49.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa58.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa70.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa48.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa60.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa54.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa62.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa23.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa45.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa51.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa27.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa62.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa32.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa26.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa24.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa12.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa58.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa70.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa48.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa60.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa49.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa47.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa60.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa48.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa12.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa49.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa35.jpg to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa23.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa62.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa54.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa26.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa32.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa51.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa45.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa27.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa47.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa12.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa70.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa58.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa24.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa23.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa27.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa32.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa26.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa54.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa62.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa60.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa48.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa24.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa35.jpg to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa49.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa47.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa35.jpg to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa24.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa70.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa58.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa12.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa32.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa26.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa23.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa27.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa45.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa51.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa62.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa54.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa51.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa45.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa23.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa49.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa35.jpg to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa47.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa48.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa60.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa58.JPG to data-validation/pa
# Moved Normalized_Augmented_3_resized_pa70.JPG to data-validation/pa
# Moved Normalized_Augmented_2_resized_pa12.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa24.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa47.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa27.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa51.JPG to data-validation/pa
# Moved Normalized_Augmented_0_resized_pa45.JPG to data-validation/pa
# Moved Normalized_Augmented_4_resized_pa54.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa26.JPG to data-validation/pa
# Moved Normalized_Augmented_1_resized_pa32.JPG to data-validation/pa
# Moved pa20.JPG to data-test/pa
# Moved pa21.JPG to data-test/pa
# Moved pa22.JPG to data-test/pa
# Moved pa33.JPG to data-test/pa
# Moved pa4.JPG to data-test/pa
# Moved pa69.jpg to data-test/pa
# Moved pa2.JPG to data-test/pa
# Moved pa61.JPG to data-test/pa
# Moved Normalized_Augmented_1_resized_p11.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p68.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p60.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p48.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p35.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p19.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p21.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p31.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p25.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p7.jfif to data-train/p
# Moved Normalized_Augmented_3_resized_p30.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p20.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p34.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p61.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p55.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p41.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p69.jpg to data-train/p
# Moved Normalized_Augmented_1_resized_p10.jpg to data-train/p
# Moved Normalized_Augmented_1_resized_p12.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p57.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p43.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p63.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p22.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p36.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p32.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p33.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p37.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p23.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p14.jfif to data-train/p
# Moved Normalized_Augmented_2_resized_p56.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p46.jpg to data-train/p
# Moved Normalized_Augmented_0_resized_p66.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p23.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p37.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p33.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p32.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p36.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p22.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p67.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p47.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p28.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p51.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p59.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p65.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p34.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p20.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p30.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p25.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p31.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p21.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p19.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p35.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p64.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p70.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p13.jfif to data-train/p
# Moved Normalized_Augmented_0_resized_p58.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p50.jpg to data-train/p
# Moved Normalized_Augmented_1_resized_p29.jpg to data-train/p
# Moved Normalized_Augmented_1_resized_p66.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p23.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p37.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p56.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p46.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p47.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p43.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p57.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p36.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p22.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p67.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p65.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p59.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p34.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p20.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p14.jfif to data-train/p
# Moved Normalized_Augmented_0_resized_p28.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p41.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p55.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p69.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p51.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p50.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p68.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p29.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p7.jfif to data-train/p
# Moved Normalized_Augmented_2_resized_p21.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p35.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p58.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p64.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p70.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p48.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p60.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p31.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p25.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p19.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p7.jfif to data-train/p
# Moved Normalized_Augmented_0_resized_p11.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p68.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p50.jpg to data-train/p
# Moved Normalized_Augmented_4_resized_p51.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p69.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p55.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p41.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p10.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p30.jpg to data-train/p
# Moved Normalized_Augmented_1_resized_p61.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p63.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p32.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p12.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p13.jfif to data-train/p
# Moved Normalized_Augmented_3_resized_p57.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p43.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p47.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p46.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p56.JPG to data-train/p
# Moved Normalized_Augmented_2_resized_p33.jpg to data-train/p
# Moved Normalized_Augmented_1_resized_p47.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p36.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p22.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p63.jpg to data-train/p
# Moved Normalized_Augmented_3_resized_p67.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p14.jfif to data-train/p
# Moved Normalized_Augmented_3_resized_p66.JPG to data-train/p
# Moved Normalized_Augmented_0_resized_p23.jpg to data-train/p
# Moved Normalized_Augmented_0_resized_p37.JPG to data-train/p
# Moved Normalized_Augmented_1_resized_p46.jpg to data-train/p
# Moved Normalized_Augmented_1_resized_p50.jpg to data-train/p
# Moved Normalized_Augmented_2_resized_p29.jpg to data-train/p
# Moved Normalized_Augmented_0_resized_p5.jpg to data-train/p
# Moved Normalized_Augmented_0_resized_p21.jpg to data-train/p
# Moved Normalized_Augmented_0_resized_p35.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p58.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p60.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p64.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p70.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p48.JPG to data-train/p
# Moved Normalized_Augmented_3_resized_p65.JPG to data-train/p
# Moved Normalized_Augmented_4_resized_p61.JPG to data-train/p
# ...
# Moved Normalized_Augmented_0_resized_fu54.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu68.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu22.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu50.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu44.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu9.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu46.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu20.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu34.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu42.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu57.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu43.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu21.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu47.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu53.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu57.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu43.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu25.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu31.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu19.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu47.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu53.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu65.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu59.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu13.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu6.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu7.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu12.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu58.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu70.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu46.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu18.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu24.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu42.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu40.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu54.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu68.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu26.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu50.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu44.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu66.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu5.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu4.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu39.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu67.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu45.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu51.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu27.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu33.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu69.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu58.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu70.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu42.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu9.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu34.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu20.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu21.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu43.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu57.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu65.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu59.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu67.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu69.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu23.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu37.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu22.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu54.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu40.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu68.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu62.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu14.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu28.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu66.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu7.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu62.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu66.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu44.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu50.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu26.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu33.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu27.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu51.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu45.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu67.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu39.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu6.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu4.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu13.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu65.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu59.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu53.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu47.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu31.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu25.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu19.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu18.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu24.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu46.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu58.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu70.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu12.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu5.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu13.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu7.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu21.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu57.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu43.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu42.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu20.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu34.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu6.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu12.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu62.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu28.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu4.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu14.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu22.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu68.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu40.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu54.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu69.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu37.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu23.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu5.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu9.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu39.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu9.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu67.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu39.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu27.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu33.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu45.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu51.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu50.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu44.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu26.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu66.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu28.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu14.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu70.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu58.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu12.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu24.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu18.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu46.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu47.JPG to data-train/fu
# Moved Normalized_Augmented_2_resized_fu53.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu19.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu25.JPG to data-train/fu
# Moved Normalized_Augmented_3_resized_fu31.JPG to data-train/fu
# Moved Normalized_Augmented_0_resized_fu13.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu59.JPG to data-train/fu
# Moved Normalized_Augmented_1_resized_fu65.JPG to data-train/fu
# Moved Normalized_Augmented_4_resized_fu32.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu2.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu36.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu15.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu41.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu55.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu3.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu35.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu49.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu61.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu60.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu48.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu16.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu56.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu35.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu3.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu11.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu38.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu10.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu32.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu2.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu36.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu55.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu41.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu15.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu36.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu56.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu48.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu60.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu3.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu16.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu2.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu61.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu49.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu35.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu56.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu32.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu10.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu38.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu11.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu55.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu41.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu16.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu48.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu60.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu56.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu35.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu61.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu49.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu2.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu15.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu41.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu55.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu36.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu3.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu10.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu38.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu32.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu11.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu61.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu49.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu48.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu60.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu49.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu61.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu35.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu56.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu16.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu60.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu48.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu38.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu10.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu36.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu55.JPG to data-validation/fu
# Moved Normalized_Augmented_2_resized_fu41.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu15.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu11.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu15.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu11.JPG to data-validation/fu
# Moved Normalized_Augmented_3_resized_fu32.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu38.JPG to data-validation/fu
# Moved Normalized_Augmented_0_resized_fu10.JPG to data-validation/fu
# Moved Normalized_Augmented_4_resized_fu16.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu2.JPG to data-validation/fu
# Moved Normalized_Augmented_1_resized_fu3.JPG to data-validation/fu
# Moved fu63.JPG to data-test/fu
# Moved fu64.JPG to data-test/fu
# Moved fu8.JPG to data-test/fu
# Moved fu29.JPG to data-test/fu
# Moved fu17.JPG to data-test/fu
# Moved fu30.JPG to data-test/fu
# Moved fu1.jpg to data-test/fu
# Moved fu52.JPG to data-test/fu
#
# Contents of data-train:
#   n: 225 images
#   f: 225 images
#   pa: 225 images
#   fu: 225 images
#   p: 225 images
#
# Contents of data-validation:
#   n: 85 images
#   f: 85 images
#   pa: 85 images
#   fu: 85 images
#   p: 85 images
#
# Contents of data-test:
#   n: 8 images
#   f: 8 images
#   pa: 8 images
#   fu: 8 images
#   p: 8 images

# %% [markdown]
# #  4. Modelling Data CNN with Mobile-Net Transfer Learning

# %% [markdown]
# At this stage, code sets up a deep CNN for image classification using images from data-train, data-validation, and data-test. It builds a CNN with five convolutional layers, batch normalization, max pooling, and a fully connected layer with regularization. The model is compiled with RMSprop, trained for 50 epochs, and evaluated on the test set. Accuracy and loss are plotted, and the trained model is saved for future use.

# %% [markdown]
# **A. Data Preparation and Generator Setup**

# %% [markdown]
# The code sets up a data generator for training, validation, and testing in image classification tasks. This generator facilitates efficient loading and grouping of image data for model training, validation, and testing.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data generator for training with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.3,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

# Data generator for validation and test without augmentation
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Data generators for train, validation, and test datasets
train_generator = train_datagen.flow_from_directory(
    'data-train',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_test_datagen.flow_from_directory(
    'data-validation',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

test_generator = val_test_datagen.flow_from_directory(
    'data-test',
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 1110 images belonging to 5 classes.
# Found 415 images belonging to 5 classes.
# Found 40 images belonging to 5 classes.

# %% [markdown]
# **B. CNN Model Architecture**

# %% [markdown]
# The code defines a CNN model using transfer learning with a pre-trained InceptionV3 model. It freezes the initial layers, fine-tunes the last 50 layers, and adds a global average pooling layer, two fully connected layers with L2 regularization, Batch Normalization, and Dropout. The output layer uses softmax for multi-class classification, and a learning rate scheduler halves the learning rate every 15 epochs.

# %%
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam

# Load MobileNet model pre-trained on ImageNet, exclude top layers
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze all layers except the last 30
for layer in base_model.layers[:-30]:
    layer.trainable = False

# Build model
model = Sequential([
    base_model,
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dropout(0.4),
    Dense(train_generator.num_classes, activation='softmax')  # Output layer
])

# %% [markdown]
# **C. Model Compilation and Training**

# %% [markdown]
# The code compiles and trains a deep learning model using the RMSprop optimizer with a learning rate of 0.0005, categorical cross-entropy loss, and accuracy as the metric. It trains for 50 epochs using data from `train_generator` and `val_generator`, applying a `LearningRateScheduler` to halve the learning rate after 15 epochs. The model is based on a pre-trained InceptionV3, fine-tuned with transfer learning, and frozen layers for improved training efficiency.

# %%
# print the model summary (optional)
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenet_1.00_224 (Functional) │ (None, 7, 7, 1024)     │     3,228,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           645 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,360,709 (12.82 MB)
#  Trainable params: 2,527,493 (9.64 MB)
#  Non-trainable params: 833,216 (3.18 MB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Compile model
model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=10, 
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-6
)

# Train model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=val_generator,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.3260 - loss: 1.7793
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 18s 464ms/step - accuracy: 0.3283 - loss: 1.7729 - val_accuracy: 0.2771 - val_loss: 2.5314 - learning_rate: 1.0000e-04
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.5519 - loss: 1.1490 - val_accuracy: 0.2699 - val_loss: 2.6499 - learning_rate: 1.0000e-04
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.6074 - loss: 0.9935 - val_accuracy: 0.3928 - val_loss: 2.0795 - learning_rate: 1.0000e-04
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.6659 - loss: 0.8694 - val_accuracy: 0.4434 - val_loss: 1.7102 - learning_rate: 1.0000e-04
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 461ms/step - accuracy: 0.7015 - loss: 0.7917 - val_accuracy: 0.5108 - val_loss: 1.5084 - learning_rate: 1.0000e-04
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 463ms/step - accuracy: 0.7319 - loss: 0.7095 - val_accuracy: 0.4771 - val_loss: 1.4991 - learning_rate: 1.0000e-04
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 464ms/step - accuracy: 0.7754 - loss: 0.6272 - val_accuracy: 0.6337 - val_loss: 1.0318 - learning_rate: 1.0000e-04
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 460ms/step - accuracy: 0.7681 - loss: 0.6119 - val_accuracy: 0.6217 - val_loss: 1.0076 - learning_rate: 1.0000e-04
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 461ms/step - accuracy: 0.7832 - loss: 0.5978 - val_accuracy: 0.6892 - val_loss: 0.8361 - learning_rate: 1.0000e-04
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 459ms/step - accuracy: 0.8249 - loss: 0.4780 - val_accuracy: 0.6988 - val_loss: 0.7742 - learning_rate: 1.0000e-04
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.8085 - loss: 0.4846 - val_accuracy: 0.7084 - val_loss: 0.7749 - learning_rate: 1.0000e-04
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 464ms/step - accuracy: 0.8408 - loss: 0.4438 - val_accuracy: 0.6771 - val_loss: 0.7866 - learning_rate: 1.0000e-04
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.8399 - loss: 0.4457 - val_accuracy: 0.7181 - val_loss: 0.7082 - learning_rate: 1.0000e-04
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 460ms/step - accuracy: 0.8304 - loss: 0.4413 - val_accuracy: 0.7133 - val_loss: 0.7855 - learning_rate: 1.0000e-04
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 461ms/step - accuracy: 0.8684 - loss: 0.3955 - val_accuracy: 0.7277 - val_loss: 0.7578 - learning_rate: 1.0000e-04
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 459ms/step - accuracy: 0.8562 - loss: 0.3855 - val_accuracy: 0.7133 - val_loss: 0.8376 - learning_rate: 1.0000e-04
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 456ms/step - accuracy: 0.8572 - loss: 0.4040 - val_accuracy: 0.7181 - val_loss: 0.7950 - learning_rate: 1.0000e-04
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 456ms/step - accuracy: 0.8813 - loss: 0.3607 - val_accuracy: 0.7422 - val_loss: 0.7817 - learning_rate: 1.0000e-04
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 462ms/step - accuracy: 0.9003 - loss: 0.2699 - val_accuracy: 0.7614 - val_loss: 0.7208 - learning_rate: 5.0000e-05
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 460ms/step - accuracy: 0.9011 - loss: 0.3029 - val_accuracy: 0.7663 - val_loss: 0.7137 - learning_rate: 5.0000e-05
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.9078 - loss: 0.2766 - val_accuracy: 0.7590 - val_loss: 0.7251 - learning_rate: 5.0000e-05
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.8830 - loss: 0.3202 - val_accuracy: 0.7277 - val_loss: 0.7473 - learning_rate: 5.0000e-05
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.8891 - loss: 0.3110 - val_accuracy: 0.7518 - val_loss: 0.7318 - learning_rate: 5.0000e-05

# %% [markdown]
# **D. Plotting Model Accuracy and Loss**

# %% [markdown]
# The code visualizes the model's training progress by plotting accuracy and loss for both training and validation datasets across epochs, helping to assess model performance and generalization.

# %%
# plot accuracy and loss
plt.figure(figsize=(12, 4))

# plot accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# plot loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# **E. Model Evaluation on Test Data**

# %% [markdown]
# The code evaluates the trained model on the test data and prints the test accuracy as a percentage, helping to assess the model's performance on unseen data.

# %%
# evaluate the model on the test data
test_loss, test_acc = model.evaluate(
    test_generator,
    steps=test_generator.samples // test_generator.batch_size
)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7812 - loss: 0.8690
# Test Accuracy: 78.12%

# %% [markdown]
# **F. Model Evaluation Summary**

# %% [markdown]
# The code prints a summary of the model's performance, showing the final training accuracy, validation accuracy, and test accuracy as percentages, providing an overview of how well the model performed during training and on unseen data.

# %%
# summary of model evaluation
print("\nModel Evaluation Summary:")

print(f"Final Train Accuracy: {history.history['accuracy'][-1] * 100:.2f}%")
print(f"Final Validation Accuracy: {history.history['val_accuracy'][-1] * 100:.2f}%")
print(f"Final Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Model Evaluation Summary:
# Final Train Accuracy: 89.55%
# Final Validation Accuracy: 75.18%
# Final Test Accuracy: 78.12%

# %% [markdown]
# **G. Saving Model**

# %% [markdown]
# The code saves the trained model to a file named 'model-dermaseer.keras' and prints a confirmation message to indicate the model has been successfully saved.

# %%
# Save the model to a file using Keras
model.save('model-dermaseer-mobilenet.keras')

# Print a message to confirm the model has been saved successfully
print("Model has been saved as 'model-dermaseer-mobilenet.keras' using Keras")
# Out:
# Model has been saved as 'model-dermaseer-mobilenet.keras' using Keras

# %% [markdown]
# # 5. Prediction

# %% [markdown]
# At this stage, the acne type prediction process is carried out using the trained model. The code defines a function `predict_acne_type` to preprocess the uploaded image, make predictions, and display the results along with probabilities for each acne type. The code uses `ipywidgets` to create a simple interactive file upload widget where users can upload images. Once uploaded, the image is processed, predictions are made, and the results are displayed.

# %%
# check class indices after creating the train_generator
print("Class indices:", train_generator.class_indices)
# Out:
# Class indices: {'f': 0, 'fu': 1, 'n': 2, 'p': 3, 'pa': 4}

# %%
# mapping class from index to class name
class_indices = {0: 'f', 1: 'fu', 2: 'n', 3: 'p', 4: 'pa'}

def predict_acne_type(img_path, model):
    # load and preprocess the image
    img = image.load_img(img_path, target_size=(150, 150))  # size should match the model input size
    img_array = image.img_to_array(img)  # convert image to array
    img_array = np.expand_dims(img_array, axis=0)  # add batch dimension
    img_array /= 255.0  # normalize according to the scale used during training

    # make predictions
    predictions = model.predict(img_array)
    predicted_class_index = np.argmax(predictions[0])  # get the index with the highest probability
    predicted_class_label = class_indices[predicted_class_index]  # convert index to class label

    # print the prediction result
    print(f"Prediction Result: {predicted_class_label} With Probability {predictions[0][predicted_class_index]:.2f}")

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from IPython.display import display, Image
import ipywidgets as widgets
from io import BytesIO
from PIL import Image as PILImage

# Load the trained model
model = load_model('model-dermaseer-mobilenet.keras')  # replace with the path to your model

# Mapping class indices
class_indices = {0: 'f', 1: 'fu', 2: 'n', 3: 'p', 4: 'pa'}
class_labels = list(class_indices.values())

# Prediction function
def predict_acne_type(img_path, model):
    try:
        # Ensure the image size matches the model's input size
        img = image.load_img(img_path, target_size=(224, 224))  # Adjust target_size as needed
        img_array = image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array /= 255.0  # Normalize to [0, 1]

        # Make predictions
        predictions = model.predict(img_array)[0]
        predicted_class_index = np.argmax(predictions)
        predicted_class_label = class_indices[predicted_class_index]

        # Format results
        results = {class_labels[i]: float(predictions[i]) for i in range(len(predictions))}
        return predicted_class_label, results
    except Exception as e:
        print(f"Error While Processing Image: {e}")
        return None, {}

# Function to handle image upload
def on_upload_change(change):
    if change['new']:
        clear_output(wait=True)
        try:
            # Save the uploaded image
            file_content = change['new'][0]['content']
            file_name = change['new'][0]['name']

            # Convert the uploaded file content into an image
            img = PILImage.open(BytesIO(file_content))

            # Save the image locally
            img.save(file_name)

            # Display the uploaded image
            display(img)
            
            # Make a prediction
            predicted_label, probabilities = predict_acne_type(file_name, model)
            if predicted_label is None:
                print("Failed To Process Image. Please Upload Again.")
                return
            
            # Display prediction results
            print(f"Predicted Acne Type: {predicted_label}")
            print("Probabilities:")
            for acne_type, prob in probabilities.items():
                print(f"  {acne_type}: {prob:.2f}")

            # Add buttons to continue or delete image
            continue_button = widgets.Button(description="Continue Photo")
            delete_button = widgets.Button(description="Delete Photo")

            # "Continue photo" button function
            def on_continue_click(b):
                clear_output(wait=True)
                print("Please Upload Another Photo.")
                display(upload_widget)

            # "Delete photo" button function
            def on_delete_click(b):
                os.remove(file_name)
                clear_output(wait=True)
                print(f"Image {file_name} Has Been Deleted. Please Upload A New Photo.")
                display(upload_widget)

            # Add button actions
            continue_button.on_click(on_continue_click)
            delete_button.on_click(on_delete_click)

            # Display buttons
            display(widgets.HBox([continue_button, delete_button]))

        except Exception as e:
            print(f"An Error Occurred: {e}. Please Upload Again.")

# Widget for file upload
upload_widget = widgets.FileUpload(
    accept='image/*',  # Accept image files
    multiple=True  # Allow multiple files to be uploaded
)

# Monitor changes in the widget
upload_widget.observe(on_upload_change, names='value')

# Display the widget
display(upload_widget)
# Out:
# Please Upload Another Photo.
# FileUpload(value=({'name': 'images.jpeg', 'type': 'image/jpeg', 'size': 12431, 'content': <memory at 0x130e518…
