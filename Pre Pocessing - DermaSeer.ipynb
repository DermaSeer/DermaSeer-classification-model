# %% [markdown]
# # Capstone Project - DermaSeer

# %% [markdown]
# At this stage, the process of loading, splitting, and pre-processing the dataset is carried out. Please note that after loading the dataset, the process of splitting the dataset will be carried out into 80% training data, 15% validation data, and 5% testing data. Then, data pre-processing will be carried out, including resizing, augmentation, and normalization for training and validation data. No pre-processing is carried out on testing data.

# %% [markdown]
# # 1. Import Library

# %%
import os  # interacting with the operating system (file and directory manipulation)
from PIL import Image  # image processing (open, manipulate, and save images)
import matplotlib.pyplot as plt  # data visualization (plotting graphs and charts)
import random  # random number generation and sampling
import shutil  # high-level file operations (copying, moving, deleting files)
from collections import defaultdict  # dictionary with default values for missing keys
from torchvision import transforms  # image transformations (for machine learning and data augmentation)

# %% [markdown]
# # 2. Load Dataset

# %% [markdown]
# The dataset is obtained from kaggle with the link: https://www.kaggle.com/datasets/dinartas/skin90?resource=download. With a focus on acne detection, data was taken from 5 types of acne, including Nodules, Phlegmona, Papules, Fungal, Pustules.
# With information on the type of acne:
# - N: Nodules - Acne in the form of hard lumps that form under the surface of the skin.
# - F: Phlegmona - Acne that develops into a larger and more severe purulent infection.
# - PA: Papules - Small red pimples that appear on the skin without pus.
# - FU: Fungal - Large, inflamed pimples that occur due to bacterial infections in hair follicles.
# - P: Pustules - Pimples filled with pus that appear on the surface of the skin, often with white or yellow heads.

# %%
# path to the folder containing images
folder_path = 'dataset-acne'

# initialize lists to store images and filenames
data = []
filenames = []

# loop to read each image file in the folder
for filename in os.listdir(folder_path):
    if filename.lower().endswith(('.jpg', '.JPG', '.png', '.jfif')):  # filter for image files
        file_path = os.path.join(folder_path, filename)
        
        # open the image and append it to the data list
        img = Image.open(file_path)
        data.append(img)
        
        # append the filename to the filenames list
        filenames.append(filename)
        
print('Number Of Images Loaded:', len(data))
# Out:
# Number Of Images Loaded: 350

# %%
# display all filename
for file in filenames:
    print(file)
# Out:
# f43.JPG
# f57.JPG
# pa34.jpg
# pa20.JPG
# fu63.JPG
# p12.jpg
# n62.JPG
# n63.JPG
# fu62.JPG
# pa21.JPG
# pa35.jpg
# f56.JPG
# f42.JPG
# f54.JPG
# f40.JPG
# f68.JPG
# pa23.JPG
# pa37.jpg
# fu48.JPG
# fu60.JPG
# p11.jpg
# p39.JPG
# p14.jfif
# n49.JPG
# n61.JPG
# n60.JPG
# n48.JPG
# p38.JPG
# p10.jpg
# fu61.JPG
# fu49.JPG
# pa36.JPG
# pa22.JPG
# f69.JPG
# f41.JPG
# f55.JPG
# f51.JPG
# f45.JPG
# n9.JPG
# pa26.JPG
# pa32.JPG
# fu65.JPG
# fu59.JPG
# p28.jpg
# n64.JPG
# n70.JPG
# n58.JPG
# n59.JPG
# n65.JPG
# p15.JPG
# p29.jpg
# fu58.JPG
# fu70.JPG
# fu64.JPG
# pa33.JPG
# pa27.JPG
# n8.JPG
# f44.JPG
# f50.JPG
# f46.JPG
# f52.JPG
# pa19.JPG
# fu8.JPG
# pa31.JPG
# pa25.jpg
# fu66.JPG
# p17.JPG
# n67.JPG
# n66.JPG
# p16.JPG
# fu67.JPG
# pa24.JPG
# pa30.JPG
# fu9.JPG
# pa18.JPG
# f53.JPG
# f47.JPG
# f20.JPG
# f34.JPG
# f7.JPG
# pa57.JPG
# pa43.jpg
# fu28.JPG
# p45.jfif
# fu14.JPG
# p65.JPG
# p59.JPG
# pa6.JPG
# n29.JPG
# n15.JPG
# n14.JPG
# n28.JPG
# pa7.JPG
# p58.JPG
# p70.JPG
# p64.JPG
# fu15.JPG
# fu29.JPG
# pa42.JPG
# pa56.JPG
# f6.JPG
# f35.JPG
# f21.JPG
# f37.JPG
# f23.JPG
# f4.JPG
# pa40.JPG
# pa54.JPG
# pa68.JPG
# fu17.JPG
# p66.JPG
# pa5.jpg
# n16.JPG
# n17.JPG
# pa4.JPG
# p67.JPG
# fu16.JPG
# pa69.jpg
# pa55.JPG
# pa41.jpg
# p8.jpg
# f5.JPG
# f22.JPG
# f36.JPG
# f1.JPG
# f32.JPG
# f26.JPG
# p9.jfif
# pa45.JPG
# pa51.JPG
# fu12.JPG
# p63.jpg
# n13.JPG
# n12.JPG
# p62.JPG
# pa1.JPG
# fu13.JPG
# pa50.jpg
# pa44.JPG
# f27.JPG
# f33.JPG
# f19.JPG
# f2.JPG
# f25.JPG
# f31.JPG
# pa52.JPG
# pa46.JPG
# fu11.JPG
# fu39.JPG
# p48.JPG
# pa3.JPG
# p60.JPG
# n10.JPG
# n38.JPG
# n39.JPG
# p13.jfif
# n11.JPG
# p61.JPG
# pa2.JPG
# fu38.JPG
# p49.png
# fu10.JPG
# pa47.JPG
# pa53.jpg
# f30.JPG
# f24.JPG
# f3.JPG
# f18.JPG
# f15.JPG
# f29.JPG
# pa62.JPG
# p3.JPG
# fu35.JPG
# fu21.JPG
# p44.JPG
# p50.jpg
# n34.JPG
# n20.JPG
# n21.JPG
# n35.JPG
# p51.JPG
# fu20.JPG
# fu34.JPG
# p2.JPG
# pa63.JPG
# f28.JPG
# f14.JPG
# f16.JPG
# pa61.JPG
# pa49.JPG
# fu22.JPG
# fu36.JPG
# p53.JPG
# p47.JPG
# n23.JPG
# n37.JPG
# n36.JPG
# n22.JPG
# p46.jpg
# p52.JPG
# fu37.JPG
# fu23.JPG
# p1.jpg
# pa48.JPG
# pa60.JPG
# f17.JPG
# f13.JPG
# f8.JPG
# pa58.JPG
# p5.jpg
# pa64.JPG
# pa70.JPG
# fu27.JPG
# fu33.JPG
# p56.JPG
# p42.JPG
# pa9.jpg
# n26.JPG
# n32.JPG
# n33.JPG
# n27.JPG
# p43.JPG
# pa8.JPG
# p57.JPG
# fu32.JPG
# fu26.JPG
# pa65.JPG
# p4.jpg
# pa59.JPG
# f9.JPG
# f12.JPG
# f38.JPG
# f10.JPG
# p6.jpg
# pa67.JPG
# fu30.JPG
# fu24.JPG
# fu18.JPG
# p69.jpg
# p41.JPG
# p55.JPG
# n31.JPG
# n25.JPG
# n19.JPG
# n18.JPG
# n24.JPG
# n30.JPG
# p54.JPG
# p40.JPG
# p68.JPG
# fu19.JPG
# fu25.JPG
# fu31.JPG
# pa66.JPG
# p7.jfif
# f11.JPG
# f39.JPG
# f62.JPG
# n6.JPG
# pa15.JPG
# pa29.jpg
# fu4.JPG
# fu56.JPG
# fu42.JPG
# p27.jpg
# p33.jpg
# n57.JPG
# n43.JPG
# n42.JPG
# n56.JPG
# p32.JPG
# p26.JPG
# fu43.JPG
# fu57.JPG
# fu5.JPG
# pa28.JPG
# pa14.JPG
# n7.JPG
# f63.JPG
# f61.JPG
# f49.JPG
# n5.JPG
# pa16.JPG
# fu7.JPG
# fu69.JPG
# fu41.JPG
# fu55.JPG
# p30.jpg
# p24.JPG
# p18.jpg
# n68.JPG
# n40.JPG
# n54.JPG
# n55.JPG
# n41.JPG
# n69.JPG
# p19.jpg
# p25.JPG
# p31.JPG
# fu54.JPG
# fu40.JPG
# fu68.JPG
# fu6.JPG
# pa17.JPG
# n4.JPG
# f48.JPG
# f60.JPG
# f58.JPG
# f70.JPG
# f64.JPG
# fu2.JPG
# pa13.JPG
# fu44.JPG
# fu50.JPG
# p35.JPG
# p21.jpg
# n45.JPG
# n51.JPG
# n50.JPG
# n44.JPG
# p20.jpg
# p34.JPG
# fu51.JPG
# fu45.JPG
# pa12.JPG
# fu3.JPG
# n1.JPG
# f65.JPG
# f59.JPG
# f67.JPG
# n3.JPG
# pa38.jpg
# fu1.jpg
# pa10.JPG
# fu53.JPG
# fu47.JPG
# p22.JPG
# p36.JPG
# n52.JPG
# n46.JPG
# n47.JPG
# n53.JPG
# p37.JPG
# p23.jpg
# fu46.JPG
# fu52.JPG
# pa11.JPG
# pa39.JPG
# n2.JPG
# f66.JPG

# %%
# display the top 10 images
fig, axes = plt.subplots(2, 5, figsize=(15, 6)) 
for i, ax in enumerate(axes.flatten()[:10]): 
    # open the image file
    img_path = os.path.join(folder_path, filenames[i])
    img = Image.open(img_path)
    
    ax.imshow(img)
    ax.axis('off')  
    ax.set_title(f'Image {i+1}')  
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Splitting Dataset

# %% [markdown]
# Splitting the dataset from each class/type of acne was done. With a proportion of 75% training data, 15% validation data, and 10% testing data.

# %%
# dataset split percentages
train_percentage = 0.75  # train data 75%
val_percentage = 0.15    # validation data 15%
test_percentage = 0.10   # test data 10%

# directories for each dataset
directories = {
    'train': 'train',
    'validation': 'validation',
    'test': 'test'}

# folder where the original images are stored (dataset-acne)
dataset_folder = 'dataset-acne'  

# create directories 
for folder in directories.values():
    os.makedirs(folder, exist_ok=True)

# organize images by class (label taken from the text after the last underscore)
class_dict = defaultdict(list)
for image in os.listdir(dataset_folder):
    if image.endswith(('.jpg', '.JPG', '.png', '.jfif')):  # only image files are processed
        # get the text after the last underscore
        label_part = image.split('_')[-1]
        
        # check if the second character is a digit; if so, only take the first character
        if len(label_part) > 1 and label_part[1].isdigit():
            label = label_part[0]  # only take the first character
        else:
            label = label_part[:2]  # take the first two characters if both are letters
            
        class_dict[label].append(image)

# split the images by class and count the number for each category
split_counts = {
    'train': defaultdict(int),
    'validation': defaultdict(int),
    'test': defaultdict(int)
}

# function to copy images to the appropriate folder
def copy_images(image_list, source_folder, destination_folder, class_name):
    # create sub-folder for the class name
    class_folder = os.path.join(destination_folder, class_name)
    os.makedirs(class_folder, exist_ok=True)
    
    # copy images to the class folder
    for image in image_list:
        shutil.copy(os.path.join(source_folder, image), os.path.join(class_folder, image))

# process the split and copy the images
for label, images in class_dict.items():
    random.shuffle(images)
    
    total_images = len(images)
    train_count = int(train_percentage * total_images)
    val_count = int(val_percentage * total_images)
    test_count = total_images - train_count - val_count

    # split the images for each dataset
    splits = {
        'train': images[:train_count],
        'validation': images[train_count:train_count + val_count],
        'test': images[train_count + val_count:]
    }

    # copy the images to the respective folders and count the numbers
    for split, image_list in splits.items():
        copy_images(image_list, dataset_folder, directories[split], label)
        split_counts[split][label] = len(image_list)

# output the results of the dataset split
print(f'Dataset Split Completed')
for split in ['train', 'validation', 'test']:
    print(f'\n{split.capitalize()}:')
    print(f'Total Number of Images: {sum(split_counts[split].values())}')
    for label, count in split_counts[split].items():
        print(f'{label.upper()}: {count} ({(count / sum(split_counts[split].values())) * 100:.2f}%)')
# Out:
# Dataset Split Completed
#
# Train:
# Total Number of Images: 260
# F: 52 (20.00%)
# PA: 52 (20.00%)
# FU: 52 (20.00%)
# P: 52 (20.00%)
# N: 52 (20.00%)
#
# Validation:
# Total Number of Images: 50
# F: 10 (20.00%)
# PA: 10 (20.00%)
# FU: 10 (20.00%)
# P: 10 (20.00%)
# N: 10 (20.00%)
#
# Test:
# Total Number of Images: 40
# F: 8 (20.00%)
# PA: 8 (20.00%)
# FU: 8 (20.00%)
# P: 8 (20.00%)
# N: 8 (20.00%)

# %%
# prepare data for visualization
splits = ['train', 'validation', 'test']
classes = list(split_counts['train'].keys())
split_data = {split: [split_counts[split][cls] for cls in classes] for split in splits}

# plot the data
fig, ax = plt.subplots(figsize=(10, 6))
width = 0.25  # width of each bar
x = range(len(classes))

# plot each split as a separate bar group and add text on top of each bar
for i, split in enumerate(splits):
    bars = ax.bar([pos + i * width for pos in x], split_data[split], width, label=split.capitalize())
    # Add value labels on top of each bar
    for bar in bars:
        yval = bar.get_height()
        ax.text(bar.get_x() + bar.get_width()/2, yval, f'{yval}', ha='center', va='bottom')

# add a grid background
ax.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# configure the plot
ax.set_xticks([pos + width for pos in x])
ax.set_xticklabels(classes)
ax.set_xlabel('Classes')
ax.set_ylabel('Number Of Images')
ax.set_title('Image Count Per-Class In Each Dataset Split')
ax.legend()

plt.show()

# %% [markdown]
# # 4. Pre-Processing Dataset

# %% [markdown]
# Pre-processing of the dataset was carried out with the stages of resizing images, augmentation, and also normalization for training data and validation data only.

# %% [markdown]
# **A. Resize Images**

# %% [markdown]
# This code resizes images from "train" and "validation" folders to 224x224 pixels, saves them in `resize-train` and `resize-validation` subfolders, and creates the directories if they don't exist. It processes only image files, handles errors, and tracks the paths of resized images.

# %%
# setup resize images
resize_shape = (224, 224)  # the target size for resizing images

# define the main folder for resized images
main_resize_folder = 'resize-images'  # main folder for resized images

# define subfolders for train and validation datasets
resize_train_folder = os.path.join(main_resize_folder, 'resize-train')  # output folder for resized training images
resize_validation_folder = os.path.join(main_resize_folder, 'resize-validation')  # output folder for resized validation images

# create the main resize folder and subfolders if they don't exist
os.makedirs(resize_train_folder, exist_ok=True)
os.makedirs(resize_validation_folder, exist_ok=True)

# initialize list to store resized image paths
resized_images = []

# define the source folders for train and validation datasets
folders = ['train', 'validation']
base_path = '.'  # current directory

# loop through each folder (train and validation)
for folder in folders:
    folder_path = os.path.join(base_path, folder)  # get full path of train/validation
    if os.path.exists(folder_path):
        print(f"Processing Folder: {folder_path}")
        
        # loop through the directory tree using os.walk
        for root, dirs, files in os.walk(folder_path):
            print(f"Processing Directory: {root}")
            # loop through files in each subdirectory
            for filename in files:
                # check if the file is an image
                name, ext = os.path.splitext(filename)
                if ext.lower() in ['.jpg', '.jpeg', '.png', '.jfif']:  # check for image extensions
                    file_path = os.path.join(root, filename)  # full path of the image
                    try:
                        # open the image and resize it
                        img = Image.open(file_path)
                        img = img.resize(resize_shape)
                        
                        # construct the path to save the resized image
                        if folder == 'train':
                            resized_image_path = os.path.join(resize_train_folder, f"resized_{filename}")
                        else:  # folder == 'validation'
                            resized_image_path = os.path.join(resize_validation_folder, f"resized_{filename}")
                        
                        # save the resized image
                        img.save(resized_image_path)
                        resized_images.append(resized_image_path)
                        print(f"Saved Resized Image To: {resized_image_path}")
                    except Exception as e:
                        print(f"failed to process {file_path}: {e}")
                else:
                    print(f"Skipping Non-Image File: {filename}")
    else:
        print(f"Folder {folder} Not Found At Path: {folder_path}")

# print out the resized images
print("Resized Images:", resized_images)
# Out:
# Processing Folder: ./train
# Processing Directory: ./train
# Processing Directory: ./train/n
# Saved Resized Image To: resize-images/resize-train/resized_n62.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n63.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n61.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n60.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n48.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n9.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n64.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n70.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n58.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n59.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n65.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n8.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n66.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n29.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n15.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n14.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n28.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n16.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n17.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n12.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n10.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n11.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n34.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n20.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n21.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n35.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n23.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n36.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n26.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n32.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n33.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n27.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n31.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n25.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n19.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n18.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n6.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n7.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n5.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n68.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n54.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n55.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n69.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n4.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n50.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n44.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n1.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n3.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n52.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n46.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n47.JPG
# Saved Resized Image To: resize-images/resize-train/resized_n53.JPG
# Processing Directory: ./train/f
# Saved Resized Image To: resize-images/resize-train/resized_f43.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f57.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f56.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f42.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f54.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f40.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f68.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f69.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f41.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f51.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f45.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f44.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f50.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f46.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f34.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f7.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f6.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f35.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f21.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f23.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f4.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f5.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f22.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f36.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f1.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f32.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f26.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f27.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f19.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f2.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f30.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f24.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f18.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f29.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f28.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f14.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f16.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f17.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f9.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f12.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f38.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f11.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f39.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f62.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f63.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f61.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f49.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f48.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f60.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f70.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f64.JPG
# Saved Resized Image To: resize-images/resize-train/resized_f67.JPG
# Processing Directory: ./train/pa
# Saved Resized Image To: resize-images/resize-train/resized_pa34.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa20.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa21.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa35.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa23.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa37.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa36.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa22.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa26.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa27.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa19.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa31.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa25.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa24.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa30.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa18.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa57.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa7.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa42.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa56.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa40.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa54.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa68.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa5.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa69.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa55.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa41.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa45.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa51.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa1.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa44.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa46.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa2.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa47.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa53.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa63.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa48.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa60.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa58.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa64.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa70.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa8.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa59.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa67.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa66.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa29.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa28.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa14.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa16.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa12.JPG
# Saved Resized Image To: resize-images/resize-train/resized_pa38.jpg
# Saved Resized Image To: resize-images/resize-train/resized_pa10.JPG
# Processing Directory: ./train/fu
# Saved Resized Image To: resize-images/resize-train/resized_fu63.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu62.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu48.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu60.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu49.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu65.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu59.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu64.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu8.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu66.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu67.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu9.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu28.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu14.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu15.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu29.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu12.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu11.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu38.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu10.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu35.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu21.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu20.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu22.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu23.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu27.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu33.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu30.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu18.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu19.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu25.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu31.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu4.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu56.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu57.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu5.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu7.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu69.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu55.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu68.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu6.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu2.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu44.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu50.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu51.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu45.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu3.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu1.jpg
# Saved Resized Image To: resize-images/resize-train/resized_fu53.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu47.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu46.JPG
# Saved Resized Image To: resize-images/resize-train/resized_fu52.JPG
# Processing Directory: ./train/p
# Saved Resized Image To: resize-images/resize-train/resized_p12.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p11.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p14.jfif
# Saved Resized Image To: resize-images/resize-train/resized_p38.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p15.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p29.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p17.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p45.jfif
# Saved Resized Image To: resize-images/resize-train/resized_p65.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p70.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p64.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p66.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p67.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p9.jfif
# Saved Resized Image To: resize-images/resize-train/resized_p63.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p62.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p60.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p13.jfif
# Saved Resized Image To: resize-images/resize-train/resized_p61.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p49.png
# Saved Resized Image To: resize-images/resize-train/resized_p3.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p44.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p50.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p51.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p2.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p53.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p47.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p46.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p5.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p56.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p42.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p57.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p6.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p69.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p55.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p68.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p7.jfif
# Saved Resized Image To: resize-images/resize-train/resized_p27.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p33.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p32.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p26.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p30.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p24.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p18.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p19.jpg
# Saved Resized Image To: resize-images/resize-train/resized_p25.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p31.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p35.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p34.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p36.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p37.JPG
# Saved Resized Image To: resize-images/resize-train/resized_p23.jpg
# Processing Folder: ./validation
# Processing Directory: ./validation
# Processing Directory: ./validation/n
# Saved Resized Image To: resize-images/resize-validation/resized_n38.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n22.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n24.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n30.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n57.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n43.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n56.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n41.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n51.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_n2.JPG
# Processing Directory: ./validation/f
# Saved Resized Image To: resize-images/resize-validation/resized_f52.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f53.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f37.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f3.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f15.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f13.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f8.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f58.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f59.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_f66.JPG
# Processing Directory: ./validation/pa
# Saved Resized Image To: resize-images/resize-validation/resized_pa6.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa4.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa50.jpg
# Saved Resized Image To: resize-images/resize-validation/resized_pa52.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa3.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa62.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa49.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa65.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa13.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_pa39.JPG
# Processing Directory: ./validation/fu
# Saved Resized Image To: resize-images/resize-validation/resized_fu61.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu16.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu13.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu39.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu36.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu32.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu24.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu42.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu43.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_fu54.JPG
# Processing Directory: ./validation/p
# Saved Resized Image To: resize-images/resize-validation/resized_p39.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p28.jpg
# Saved Resized Image To: resize-images/resize-validation/resized_p16.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p59.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p48.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p52.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p43.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p54.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p40.JPG
# Saved Resized Image To: resize-images/resize-validation/resized_p22.JPG
# Resized Images: ['resize-images/resize-train/resized_n62.JPG', 'resize-images/resize-train/resized_n63.JPG', 'resize-images/resize-train/resized_n61.JPG', 'resize-images/resize-train/resized_n60.JPG', 'resize-images/resize-train/resized_n48.JPG', 'resize-images/resize-train/resized_n9.JPG', 'resize-images/resize-train/resized_n64.JPG', 'resize-images/resize-train/resized_n70.JPG', 'resize-images/resize-train/resized_n58.JPG', 'resize-images/resize-train/resized_n59.JPG', 'resize-images/resize-train/resized_n65.JPG', 'resize-images/resize-train/resized_n8.JPG', 'resize-images/resize-train/resized_n66.JPG', 'resize-images/resize-train/resized_n29.JPG', 'resize-images/resize-train/resized_n15.JPG', 'resize-images/resize-train/resized_n14.JPG', 'resize-images/resize-train/resized_n28.JPG', 'resize-images/resize-train/resized_n16.JPG', 'resize-images/resize-train/resized_n17.JPG', 'resize-images/resize-train/resized_n12.JPG', 'resize-images/resize-train/resized_n10.JPG', 'resize-images/resize-train/resized_n11.JPG', 'resize-images/resize-train/resized_n34.JPG', 'resize-images/resize-train/resized_n20.JPG', 'resize-images/resize-train/resized_n21.JPG', 'resize-images/resize-train/resized_n35.JPG', 'resize-images/resize-train/resized_n23.JPG', 'resize-images/resize-train/resized_n36.JPG', 'resize-images/resize-train/resized_n26.JPG', 'resize-images/resize-train/resized_n32.JPG', 'resize-images/resize-train/resized_n33.JPG', 'resize-images/resize-train/resized_n27.JPG', 'resize-images/resize-train/resized_n31.JPG', 'resize-images/resize-train/resized_n25.JPG', 'resize-images/resize-train/resized_n19.JPG', 'resize-images/resize-train/resized_n18.JPG', 'resize-images/resize-train/resized_n6.JPG', 'resize-images/resize-train/resized_n7.JPG', 'resize-images/resize-train/resized_n5.JPG', 'resize-images/resize-train/resized_n68.JPG', 'resize-images/resize-train/resized_n54.JPG', 'resize-images/resize-train/resized_n55.JPG', 'resize-images/resize-train/resized_n69.JPG', 'resize-images/resize-train/resized_n4.JPG', 'resize-images/resize-train/resized_n50.JPG', 'resize-images/resize-train/resized_n44.JPG', 'resize-images/resize-train/resized_n1.JPG', 'resize-images/resize-train/resized_n3.JPG', 'resize-images/resize-train/resized_n52.JPG', 'resize-images/resize-train/resized_n46.JPG', 'resize-images/resize-train/resized_n47.JPG', 'resize-images/resize-train/resized_n53.JPG', 'resize-images/resize-train/resized_f43.JPG', 'resize-images/resize-train/resized_f57.JPG', 'resize-images/resize-train/resized_f56.JPG', 'resize-images/resize-train/resized_f42.JPG', 'resize-images/resize-train/resized_f54.JPG', 'resize-images/resize-train/resized_f40.JPG', 'resize-images/resize-train/resized_f68.JPG', 'resize-images/resize-train/resized_f69.JPG', 'resize-images/resize-train/resized_f41.JPG', 'resize-images/resize-train/resized_f51.JPG', 'resize-images/resize-train/resized_f45.JPG', 'resize-images/resize-train/resized_f44.JPG', 'resize-images/resize-train/resized_f50.JPG', 'resize-images/resize-train/resized_f46.JPG', 'resize-images/resize-train/resized_f34.JPG', 'resize-images/resize-train/resized_f7.JPG', 'resize-images/resize-train/resized_f6.JPG', 'resize-images/resize-train/resized_f35.JPG', 'resize-images/resize-train/resized_f21.JPG', 'resize-images/resize-train/resized_f23.JPG', 'resize-images/resize-train/resized_f4.JPG', 'resize-images/resize-train/resized_f5.JPG', 'resize-images/resize-train/resized_f22.JPG', 'resize-images/resize-train/resized_f36.JPG', 'resize-images/resize-train/resized_f1.JPG', 'resize-images/resize-train/resized_f32.JPG', 'resize-images/resize-train/resized_f26.JPG', 'resize-images/resize-train/resized_f27.JPG', 'resize-images/resize-train/resized_f19.JPG', 'resize-images/resize-train/resized_f2.JPG', 'resize-images/resize-train/resized_f30.JPG', 'resize-images/resize-train/resized_f24.JPG', 'resize-images/resize-train/resized_f18.JPG', 'resize-images/resize-train/resized_f29.JPG', 'resize-images/resize-train/resized_f28.J ...

# %%
# display the first 10 resized images
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
for i, ax in enumerate(axes.flatten()[:10]):
    ax.imshow(Image.open(resized_images[i]))
    ax.axis('off')
    ax.set_title(f'Image {i+1}')
plt.tight_layout()
plt.show()

# %% [markdown]
# **B. Augmentation Images**

# %% [markdown]
# This code applies data augmentation (e.g., flips, rotation, cropping, color jitter) to images in the "resize-images" folder and saves five augmented versions per image in the "augmentation-images" folder, under `augmentation-train` and `augmentation-validation`. It ensures necessary directories exist and logs the augmentation progress.

# %%
# folder paths
resize_folder = 'resize-images'  # main folder for resized images
augmentation_folder = 'augmentation-images'  # main folder for augmented images

# create the main augmentation folder if it doesn't exist
os.makedirs(augmentation_folder, exist_ok=True)

# create the subfolders for train and validation if they don't exist
augmentation_train_folder = os.path.join(augmentation_folder, 'augmentation-train')
augmentation_validation_folder = os.path.join(augmentation_folder, 'augmentation-validation')

os.makedirs(augmentation_train_folder, exist_ok=True)
os.makedirs(augmentation_validation_folder, exist_ok=True)

# define the augmentation pipeline
transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),  # augment: random horizontal flip
    transforms.RandomVerticalFlip(),    # augment: random vertical flip
    transforms.RandomRotation(30),      # augment: random rotation up to 30 degrees
    transforms.RandomResizedCrop(128),  # augment: random crop and resize to 128x128
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),  # augment: random color jitter
    transforms.ToTensor(),              # convert image to tensor
])

# process all images in the 'resize-images' folder
for subfolder in ['resize-train', 'resize-validation']:
    folder_path = os.path.join(resize_folder, subfolder)  # get full path of resize-train or resize-validation
    if os.path.exists(folder_path):
        print(f"Processing Folder: {folder_path}")
        
        # loop through files in each subfolder
        for filename in os.listdir(folder_path):
            if filename.endswith(('.jpg', '.JPG', '.png', '.jfif')):  
                img_path = os.path.join(folder_path, filename)
                
                # open the image
                img = Image.open(img_path)
                
                # generate and save 5 augmented images for each image
                augmented_images = []
                for i in range(5):
                    augmented_img = transform(img)
                    
                    # convert back to PIL image for saving
                    augmented_img_pil = transforms.ToPILImage()(augmented_img)
                    
                    # define the path to save the augmented image
                    if subfolder == 'resize-train':
                        augmented_image_path = os.path.join(augmentation_train_folder, f"Augmented_{i}_{filename}")
                    else:  # subfolder == 'resize-validation'
                        augmented_image_path = os.path.join(augmentation_validation_folder, f"Augmented_{i}_{filename}")
                    
                    # save the augmented image
                    augmented_img_pil.save(augmented_image_path)
                    
                    # add to the list of augmented images
                    augmented_images.append(augmented_img_pil)

                print(f'Augmentation For {filename} Completed. Total {len(augmented_images)} Images Saved.')

print('Augmentation For All Images Completed.')
# Out:
# Processing Folder: resize-images/resize-train
# Augmentation For resized_f14.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f28.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n21.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa59.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n35.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p51.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p44.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p50.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n34.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa58.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n20.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa64.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa70.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f29.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu27.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu33.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu19.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu25.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu31.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f17.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa66.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n36.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p46.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p53.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p47.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n23.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa67.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f16.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu30.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu18.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu20.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f12.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n33.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n27.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa63.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa8.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p57.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p56.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p42.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n26.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n32.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu35.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu21.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p7.jfif Completed. Total 5 Images Saved.
# Augmentation For resized_fu23.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f39.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f11.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n9.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa48.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n18.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa60.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p68.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p55.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p69.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n19.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n31.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n25.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n8.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f38.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu22.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu5.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu51.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f4.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu45.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f63.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa12.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p32.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p26.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p27.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p33.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_f62.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu44.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu50.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f5.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu4.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu6.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu46.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f7.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu52.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f60.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f48.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n69.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n55.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p25.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p31.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p19.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p18.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p30.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p24.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa38.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n54.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa10.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n68.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f49.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f61.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f6.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu53.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu47.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu7.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu3.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu57.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f2.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n50.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa28.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n44.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa14.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p34.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p35.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa29.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_f70.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f64.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu56.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu2.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f1.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu68.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n47.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n53.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p37.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p23.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p36.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa16.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n52.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n46.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f67.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu69.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu55.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu1.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_fu64.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f56.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f42.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa27.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n63.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p12.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n62.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa26.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f43.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f57.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu65.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu59.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p3.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu67.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f41.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f69.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n48.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa24.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa30.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa18.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n60.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p38.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p11.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n61.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa19.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa31.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa25.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_f68.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f54.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f40.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu66.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p2.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p6.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_fu62.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f44.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f50.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n65.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa21.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa35.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n59.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p29.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p15.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n58.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa34.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_pa20.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n64.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n70.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f51.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f45.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu63.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu9.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p5.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_fu49.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n66.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa36.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa22.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p17.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa23.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa37.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_f46.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f9.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu48.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu60.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu8.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p14.jfif Completed. Total 5 Images Saved.
# Augmentation For resized_f35.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f21.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n5.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa44.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n28.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n14.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p70.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p64.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa7.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p65.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n15.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n29.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa45.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa51.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n4.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f34.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu12.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p13.jfif Completed. Total 5 Images Saved.
# Augmentation For resized_fu38.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu10.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f22.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f36.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n6.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa47.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa53.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n17.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p67.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa5.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p66.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n16.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa46.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n7.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f23.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu11.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu15.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu29.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n3.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f27.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n12.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa42.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa56.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa1.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p62.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p63.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_pa57.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f32.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f26.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p45.jfif Completed. Total 5 Images Saved.
# Augmentation For resized_fu28.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu14.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p9.jfif Completed. Total 5 Images Saved.
# Augmentation For resized_f18.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f30.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f24.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa69.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_n11.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa55.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa41.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_pa2.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p61.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p49.png Completed. Total 5 Images Saved.
# Augmentation For resized_p60.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa40.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa54.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n10.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa68.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f19.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n1.JPG Completed. Total 5 Images Saved.
# Processing Folder: resize-images/resize-validation
# Augmentation For resized_fu32.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa65.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f15.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n22.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p52.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu24.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p43.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa62.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f13.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n24.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n30.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p54.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p40.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa49.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu36.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n56.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n57.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n43.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa13.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa39.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n41.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu43.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f59.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n51.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f58.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f3.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu42.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu54.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f66.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p22.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p39.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p28.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_fu61.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f8.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f53.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p16.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f52.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu13.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa50.jpg Completed. Total 5 Images Saved.
# Augmentation For resized_p59.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa6.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa4.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa52.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_f37.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu39.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n2.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_fu16.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_pa3.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_p48.JPG Completed. Total 5 Images Saved.
# Augmentation For resized_n38.JPG Completed. Total 5 Images Saved.
# Augmentation For All Images Completed.

# %% [markdown]
# **C. Normalization Images**

# %% [markdown]
# This code normalizes images by converting pixel values to the range [0, 1] and saves them in the "normalization-images" folder. It processes images from "augmentation-images" subfolders ("augmentation-train" and "augmentation-validation") and saves the normalized images in corresponding subfolders.

# %%
# folder paths
augmentation_folder = 'augmentation-images'  # folder for augmented images
normalized_folder = 'normalization-images'  # folder for normalized images

# create the main normalization folder if it doesn't exist
os.makedirs(normalized_folder, exist_ok=True)

# create the subfolders for normalization-train and normalization-validation if they don't exist
normalization_train_folder = os.path.join(normalized_folder, 'normalization-train')
normalization_validation_folder = os.path.join(normalized_folder, 'normalization-validation')

os.makedirs(normalization_train_folder, exist_ok=True)
os.makedirs(normalization_validation_folder, exist_ok=True)

# define the normalization transformation to the range [0, 1]
normalize_transform = transforms.Compose([
    transforms.ToTensor(),  # convert the image to a tensor with the range [0, 1]
])

# process all images in the 'augmentation-images' folder
for subfolder in ['augmentation-train', 'augmentation-validation']:  # adjust subfolders for augmentation
    folder_path = os.path.join(augmentation_folder, subfolder)  # get full path of the subfolder
    if os.path.exists(folder_path):
        print(f"Processing Folder: {folder_path}")

        # loop through files in each subfolder
        for filename in os.listdir(folder_path):
            if filename.endswith(('.jpg', '.JPG', '.png', '.jfif')):  # check if the file is an image
                img_path = os.path.join(folder_path, filename)

                # open the image
                img = Image.open(img_path)

                # apply normalization
                img_normalized = normalize_transform(img)  # the image is now in tensor format with the range [0, 1]

                # check the tensor values
                print(f'Image {filename}: Min = {img_normalized.min()}, Max = {img_normalized.max()}')  # should be Min = 0.0 and Max = 1.0

                # convert back to PIL image to save
                img_normalized_pil = transforms.ToPILImage()(img_normalized)

                # define the path to save the normalized image
                if subfolder == 'augmentation-train':
                    normalized_image_path = os.path.join(normalization_train_folder, f'Normalized_{filename}')
                else:  # subfolder == 'augmentation-validation'
                    normalized_image_path = os.path.join(normalization_validation_folder, f'Normalized_{filename}')

                # save the normalized image
                img_normalized_pil.save(normalized_image_path)

        print(f'Normalization Completed For {subfolder}.')

print('Normalization For All Images Completed.')
# Out:
# Processing Folder: augmentation-images/augmentation-train
# Image Augmented_1_resized_n48.JPG: Min = 0.0, Max = 0.6235294342041016
# Image Augmented_4_resized_pa63.JPG: Min = 0.0, Max = 0.7568627595901489
# Image Augmented_1_resized_n60.JPG: Min = 0.0, Max = 0.572549045085907
# Image Augmented_2_resized_fu64.JPG: Min = 0.0, Max = 0.9960784316062927
# Image Augmented_3_resized_f49.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f61.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_2_resized_f2.JPG: Min = 0.0, Max = 0.9921568632125854
# Image Augmented_1_resized_p38.JPG: Min = 0.04313725605607033, Max = 0.9843137264251709
# Image Augmented_3_resized_fu12.JPG: Min = 0.03921568766236305, Max = 0.8392156958580017
# Image Augmented_2_resized_n25.JPG: Min = 0.0, Max = 0.6941176652908325
# Image Augmented_0_resized_fu18.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu7.JPG: Min = 0.0313725508749485, Max = 1.0
# Image Augmented_2_resized_n31.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n19.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu30.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_fu3.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_0_resized_f24.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p69.jpg: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f30.JPG: Min = 0.0, Max = 0.9137254953384399
# Image Augmented_1_resized_fu46.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p55.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f18.JPG: Min = 0.0, Max = 0.9176470637321472
# Image Augmented_1_resized_fu52.JPG: Min = 0.0, Max = 0.9098039269447327
# Image Augmented_0_resized_pa67.JPG: Min = 0.2078431397676468, Max = 0.8941176533699036
# Image Augmented_0_resized_n11.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p61.JPG: Min = 0.07450980693101883, Max = 0.8666666746139526
# Image Augmented_2_resized_f38.JPG: Min = 0.0, Max = 0.8823529481887817
# Image Augmented_3_resized_f6.JPG: Min = 0.0, Max = 0.7137255072593689
# Image Augmented_0_resized_pa2.JPG: Min = 0.0117647061124444, Max = 1.0
# Image Augmented_3_resized_n54.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa27.JPG: Min = 0.0, Max = 0.7960784435272217
# Image Augmented_3_resized_n68.JPG: Min = 0.18039216101169586, Max = 0.8196078538894653
# Image Augmented_4_resized_n50.JPG: Min = 0.0, Max = 0.843137264251709
# Image Augmented_0_resized_p49.png: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n44.JPG: Min = 0.0, Max = 0.6666666865348816
# Image Augmented_4_resized_f5.JPG: Min = 0.0, Max = 0.9176470637321472
# Image Augmented_4_resized_fu20.JPG: Min = 0.003921568859368563, Max = 0.9450980424880981
# Image Augmented_3_resized_pa45.JPG: Min = 0.250980406999588, Max = 0.8666666746139526
# Image Augmented_3_resized_p18.jpg: Min = 0.12941177189350128, Max = 1.0
# Image Augmented_4_resized_p34.JPG: Min = 0.007843137718737125, Max = 1.0
# Image Augmented_1_resized_f41.JPG: Min = 0.0, Max = 0.7882353067398071
# Image Augmented_3_resized_pa51.JPG: Min = 0.49803921580314636, Max = 1.0
# Image Augmented_1_resized_f69.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_3_resized_p24.JPG: Min = 0.43921568989753723, Max = 1.0
# Image Augmented_3_resized_p30.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p31.JPG: Min = 0.10588235408067703, Max = 0.9254902005195618
# Image Augmented_3_resized_p25.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f68.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f40.JPG: Min = 0.16078431904315948, Max = 0.800000011920929
# Image Augmented_4_resized_p35.JPG: Min = 0.019607843831181526, Max = 0.9411764740943909
# Image Augmented_3_resized_pa44.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f54.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p19.jpg: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_fu21.JPG: Min = 0.0, Max = 0.7372549176216125
# Image Augmented_4_resized_f4.JPG: Min = 0.0, Max = 0.8705882430076599
# Image Augmented_4_resized_fu35.JPG: Min = 0.0, Max = 0.8509804010391235
# Image Augmented_3_resized_n69.JPG: Min = 0.0941176488995552, Max = 1.0
# Image Augmented_3_resized_n55.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p7.jfif: Min = 0.2078431397676468, Max = 0.8509804010391235
# Image Augmented_2_resized_pa26.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa38.jpg: Min = 0.4274509847164154, Max = 1.0
# Image Augmented_2_resized_f11.JPG: Min = 0.0, Max = 0.9019607901573181
# Image Augmented_2_resized_f39.JPG: Min = 0.0, Max = 0.886274516582489
# Image Augmented_1_resized_pa10.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f7.JPG: Min = 0.0, Max = 0.9176470637321472
# Image Augmented_0_resized_p60.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_n10.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_pa66.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu53.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu47.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_0_resized_f19.JPG: Min = 0.0235294122248888, Max = 0.843137264251709
# Image Augmented_2_resized_p68.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_fu2.JPG: Min = 0.16862745583057404, Max = 0.8901960849761963
# Image Augmented_0_resized_fu31.JPG: Min = 0.0, Max = 0.9921568632125854
# Image Augmented_2_resized_n18.JPG: Min = 0.0, Max = 0.6313725709915161
# Image Augmented_0_resized_fu25.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu6.JPG: Min = 0.0, Max = 0.9176470637321472
# Image Augmented_0_resized_fu19.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_3_resized_f60.JPG: Min = 0.007843137718737125, Max = 0.8784313797950745
# Image Augmented_4_resized_f70.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_3_resized_f48.JPG: Min = 0.0, Max = 0.9137254953384399
# Image Augmented_4_resized_f64.JPG: Min = 0.07450980693101883, Max = 1.0
# Image Augmented_1_resized_p11.jpg: Min = 0.0, Max = 0.9607843160629272
# Image Augmented_1_resized_n61.JPG: Min = 0.08235294371843338, Max = 0.8588235378265381
# Image Augmented_2_resized_fu65.JPG: Min = 0.0, Max = 0.9333333373069763
# Image Augmented_2_resized_fu59.JPG: Min = 0.062745101749897, Max = 0.8745098114013672
# Image Augmented_4_resized_pa60.JPG: Min = 0.0, Max = 0.7960784435272217
# Image Augmented_2_resized_fu67.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_n63.JPG: Min = 0.0, Max = 0.8627451062202454
# Image Augmented_4_resized_pa48.JPG: Min = 0.0, Max = 0.6549019813537598
# Image Augmented_3_resized_fu11.JPG: Min = 0.06666667014360428, Max = 0.8235294222831726
# Image Augmented_3_resized_f62.JPG: Min = 0.239215686917305, Max = 0.8745098114013672
# Image Augmented_2_resized_f1.JPG: Min = 0.0, Max = 0.8274509906768799
# Image Augmented_2_resized_n32.JPG: Min = 0.0, Max = 0.9372549057006836
# Image Augmented_3_resized_fu4.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n26.JPG: Min = 0.29019609093666077, Max = 0.8549019694328308
# Image Augmented_0_resized_fu33.JPG: Min = 0.0, Max = 0.8470588326454163
# Image Augmented_0_resized_fu27.JPG: Min = 0.0, Max = 0.9254902005195618
# Image Augmented_1_resized_n8.JPG: Min = 0.27843138575553894, Max = 0.8823529481887817
# Image Augmented_0_resized_f27.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu51.JPG: Min = 0.0, Max = 0.9176470637321472
# Image Augmented_2_resized_p42.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p56.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_1_resized_fu45.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_pa70.JPG: Min = 0.003921568859368563, Max = 0.9176470637321472
# Image Augmented_0_resized_pa64.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_0_resized_pa58.JPG: Min = 0.0, Max = 0.8941176533699036
# Image Augmented_0_resized_n12.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa12.JPG: Min = 0.2235294133424759, Max = 0.7607843279838562
# Image Augmented_3_resized_f5.JPG: Min = 0.062745101749897, Max = 0.8745098114013672
# Image Augmented_0_resized_p62.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_pa1.JPG: Min = 0.21176470816135406, Max = 1.0
# Image Augmented_2_resized_pa30.JPG: Min = 0.0, Max = 0.9098039269447327
# Image Augmented_2_resized_pa24.JPG: Min = 0.0, Max = 0.9411764740943909
# Image Augmented_4_resized_n47.JPG: Min = 0.21568627655506134, Max = 0.772549033164978
# Image Augmented_4_resized_fu23.JPG: Min = 0.0, Max = 0.9843137264251709
# Image Augmented_4_resized_f6.JPG: Min = 0.0, Max = 0.7529411911964417
# Image Augmented_2_resized_pa18.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n53.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_p37.JPG: Min = 0.0, Max = 0.9098039269447327
# Image Augmented_1_resized_f42.JPG: Min = 0.0, Max = 0.9098039269447327
# Image Augmented_4_resized_p23.jpg: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f56.JPG: Min = 0.019607843831181526, Max = 0.7764706015586853
# Image Augmented_3_resized_pa46.JPG: Min = 0.16078431904315948, Max = 0.7490196228027344
# Image Augmented_3_resized_p33.jpg: Min = 0.19607843458652496, Max = 0.9058823585510254
# Image Augmented_3_resized_p27.jpg: Min = 0.0, Max = 0.9333333373069763
# Image Augmented_3_resized_p26.JPG: Min = 0.09019608050584793, Max = 1.0
# Image Augmented_3_resized_p32.JPG: Min = 0.0, Max = 0.8941176533699036
# Image Augmented_1_resized_f57.JPG: Min = 0.1882352977991104, Max = 1.0
# Image Augmented_3_resized_pa47.JPG: Min = 0.01568627543747425, Max = 0.7921568751335144
# Image Augmented_3_resized_pa53.jpg: Min = 0.24705882370471954, Max = 0.9450980424880981
# Image Augmented_1_resized_f43.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_4_resized_p36.JPG: Min = 0.18431372940540314, Max = 1.0
# Image Augmented_2_resized_pa19.JPG: Min = 0.3803921639919281, Max = 1.0
# Image Augmented_4_resized_n52.JPG: Min = 0.0, Max = 0.9843137264251709
# Image Augmented_4_resized_f7.JPG: Min = 0.0941176488995552, Max = 0.7764706015586853
# Image Augmented_4_resized_fu22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n46.JPG: Min = 0.14509804546833038, Max = 0.9843137264251709
# Image Augmented_2_resized_pa25.jpg: Min = 0.21176470816135406, Max = 1.0
# Image Augmented_2_resized_pa31.JPG: Min = 0.1921568661928177, Max = 0.9019607901573181
# Image Augmented_2_resized_f12.JPG: Min = 0.07450980693101883, Max = 0.8549019694328308
# Image Augmented_0_resized_p63.jpg: Min = 0.0, Max = 0.9137254953384399
# Image Augmented_3_resized_f4.JPG: Min = 0.07450980693101883, Max = 1.0
# Image Augmented_0_resized_pa59.JPG: Min = 0.239215686917305, Max = 0.6705882549285889
# Image Augmented_2_resized_p57.JPG: Min = 0.0, Max = 0.8666666746139526
# Image Augmented_1_resized_fu44.JPG: Min = 0.3490196168422699, Max = 0.7686274647712708
# Image Augmented_1_resized_fu50.JPG: Min = 0.05882352963089943, Max = 1.0
# Image Augmented_2_resized_pa8.JPG: Min = 0.47058823704719543, Max = 1.0
# Image Augmented_0_resized_f26.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_n9.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f32.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p13.jfif: Min = 0.0, Max = 0.7686274647712708
# Image Augmented_4_resized_fu1.jpg: Min = 0.0, Max = 0.9725490212440491
# Image Augmented_2_resized_n27.JPG: Min = 0.0, Max = 0.9215686321258545
# Image Augmented_2_resized_n33.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu5.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f63.JPG: Min = 0.0, Max = 0.9764705896377563
# Image Augmented_3_resized_fu10.JPG: Min = 0.14509804546833038, Max = 1.0
# Image Augmented_0_resized_p9.jfif: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_f67.JPG: Min = 0.0117647061124444, Max = 0.9843137264251709
# Image Augmented_1_resized_p12.jpg: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_3_resized_fu38.JPG: Min = 0.0, Max = 0.7372549176216125
# Image Augmented_2_resized_fu66.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_1_resized_n62.JPG: Min = 0.22745098173618317, Max = 0.8117647171020508
# Image Augmented_4_resized_pa59.JPG: Min = 0.0, Max = 0.9215686321258545
# Image Augmented_1_resized_n66.JPG: Min = 0.0, Max = 0.9882352948188782
# Image Augmented_2_resized_fu62.JPG: Min = 0.007843137718737125, Max = 0.8705882430076599
# Image Augmented_3_resized_fu14.JPG: Min = 0.3490196168422699, Max = 0.9529411792755127
# Image Augmented_3_resized_f67.JPG: Min = 0.0, Max = 0.686274528503418
# Image Augmented_2_resized_f4.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_3_resized_p45.jfif: Min = 0.24313725531101227, Max = 1.0
# Image Augmented_3_resized_fu28.JPG: Min = 0.0, Max = 0.8039215803146362
# Image Augmented_4_resized_f63.JPG: Min = 0.2980392277240753, Max = 0.9686274528503418
# Image Augmented_4_resized_fu5.JPG: Min = 0.06666667014360428, Max = 0.843137264251709
# Image Augmented_0_resized_fu22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu1.jpg: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_2_resized_n23.JPG: Min = 0.16078431904315948, Max = 1.0
# Image Augmented_2_resized_p47.JPG: Min = 0.3333333432674408, Max = 0.95686274766922
# Image Augmented_2_resized_p53.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_0_resized_f36.JPG: Min = 0.3490196168422699, Max = 0.9882352948188782
# Image Augmented_1_resized_fu68.JPG: Min = 0.5254902243614197, Max = 0.8627451062202454
# Image Augmented_0_resized_f22.JPG: Min = 0.10980392247438431, Max = 0.843137264251709
# Image Augmented_0_resized_n17.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_1_resized_fu9.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_f16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p67.JPG: Min = 0.27450981736183167, Max = 1.0
# Image Augmented_2_resized_pa35.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_n46.JPG: Min = 0.13725490868091583, Max = 0.8470588326454163
# Image Augmented_3_resized_n52.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_2_resized_pa21.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p36.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_n9.JPG: Min = 0.4274509847164154, Max = 1.0
# Image Augmented_4_resized_p32.JPG: Min = 0.2549019753932953, Max = 0.9137254953384399
# Image Augmented_3_resized_pa57.JPG: Min = 0.3450980484485626, Max = 0.8666666746139526
# Image Augmented_4_resized_p26.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_3_resized_pa42.JPG: Min = 0.47843137383461, Max = 1.0
# Image Augmented_4_resized_p27.jpg: Min = 0.0, Max = 0.8941176533699036
# Image Augmented_1_resized_f46.JPG: Min = 0.0, Max = 0.6980392336845398
# Image Augmented_4_resized_p33.jpg: Min = 0.0, Max = 0.8705882430076599
# Image Augmented_3_resized_pa56.JPG: Min = 0.3450980484485626, Max = 1.0
# Image Augmented_3_resized_p23.jpg: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_0_resized_n8.JPG: Min = 0.3529411852359772, Max = 1.0
# Image Augmented_3_resized_p37.JPG: Min = 0.0, Max = 0.8196078538894653
# Image Augmented_3_resized_n53.JPG: Min = 0.0, Max = 0.7686274647712708
# Image Augmented_2_resized_pa20.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa34.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_n47.JPG: Min = 0.0, Max = 0.8666666746139526
# Image Augmented_4_resized_fu33.JPG: Min = 0.06666667014360428, Max = 0.686274528503418
# Image Augmented_4_resized_f2.JPG: Min = 0.062745101749897, Max = 0.8274509906768799
# Image Augmented_4_resized_fu27.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p66.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f1.JPG: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_1_resized_pa16.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_2_resized_f17.JPG: Min = 0.0, Max = 0.7764706015586853
# Image Augmented_0_resized_pa5.jpg: Min = 0.01568627543747425, Max = 1.0
# Image Augmented_0_resized_pa60.JPG: Min = 0.04313725605607033, Max = 0.9607843160629272
# Image Augmented_1_resized_fu8.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_n16.JPG: Min = 0.23529411852359772, Max = 0.7607843279838562
# Image Augmented_0_resized_pa48.JPG: Min = 0.0, Max = 0.6549019813537598
# Image Augmented_0_resized_f23.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_1_resized_fu69.JPG: Min = 0.40784314274787903, Max = 0.9607843160629272
# Image Augmented_2_resized_p46.jpg: Min = 0.2862745225429535, Max = 1.0
# Image Augmented_1_resized_fu55.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n36.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_0_resized_fu23.JPG: Min = 0.0, Max = 0.7529411911964417
# Image Augmented_4_resized_fu4.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_f62.JPG: Min = 0.0, Max = 0.8117647171020508
# Image Augmented_1_resized_p17.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu29.JPG: Min = 0.0, Max = 0.9647058844566345
# Image Augmented_2_resized_f5.JPG: Min = 0.003921568859368563, Max = 0.8941176533699036
# Image Augmented_3_resized_fu15.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_pa70.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_pa64.JPG: Min = 0.0, Max = 0.8784313797950745
# Image Augmented_2_resized_fu63.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_pa58.JPG: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_1_resized_n65.JPG: Min = 0.0, Max = 0.9411764740943909
# Image Augmented_1_resized_n59.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_4_resized_pa66.JPG: Min = 0.3176470696926117, Max = 0.9607843160629272
# Image Augmented_2_resized_fu49.JPG: Min = 0.0, Max = 0.7607843279838562
# Image Augmented_3_resized_f64.JPG: Min = 0.0, Max = 0.9607843160629272
# Image Augmented_1_resized_p29.jpg: Min = 0.0235294122248888, Max = 1.0
# Image Augmented_2_resized_f7.JPG: Min = 0.06666667014360428, Max = 0.7176470756530762
# Image Augmented_4_resized_f48.JPG: Min = 0.0, Max = 0.9058823585510254
# Image Augmented_3_resized_f70.JPG: Min = 0.0, Max = 0.929411768913269
# Image Augmented_1_resized_p15.JPG: Min = 0.4627451002597809, Max = 0.9843137264251709
# Image Augmented_4_resized_f60.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu21.JPG: Min = 0.0, Max = 0.686274528503418
# Image Augmented_0_resized_fu35.JPG: Min = 0.2549019753932953, Max = 0.9176470637321472
# Image Augmented_4_resized_fu6.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n20.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n34.JPG: Min = 0.0117647061124444, Max = 0.7450980544090271
# Image Augmented_3_resized_fu2.JPG: Min = 0.0, Max = 0.9607843160629272
# Image Augmented_2_resized_p50.jpg: Min = 0.0, Max = 0.9921568632125854
# Image Augmented_1_resized_fu57.JPG: Min = 0.2549019753932953, Max = 1.0
# Image Augmented_2_resized_p44.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f21.JPG: Min = 0.06666667014360428, Max = 1.0
# Image Augmented_0_resized_f35.JPG: Min = 0.0, Max = 0.9137254953384399
# Image Augmented_0_resized_n14.JPG: Min = 0.05882352963089943, Max = 0.9254902005195618
# Image Augmented_0_resized_n28.JPG: Min = 0.0, Max = 0.6666666865348816
# Image Augmented_1_resized_pa28.JPG: Min = 0.3176470696926117, Max = 0.9019607901573181
# Image Augmented_0_resized_pa7.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_f29.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p64.JPG: Min = 0.0, Max = 0.8274509906768799
# Image Augmented_1_resized_pa14.JPG: Min = 0.0, Max = 0.929411768913269
# Image Augmented_0_resized_p70.JPG: Min = 0.027450980618596077, Max = 0.7137255072593689
# Image Augmented_4_resized_fu31.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n55.JPG: Min = 0.0, Max = 0.8705882430076599
# Image Augmented_4_resized_fu25.JPG: Min = 0.3686274588108063, Max = 0.843137264251709
# Image Augmented_2_resized_pa22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n69.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_4_resized_fu19.JPG: Min = 0.0, Max = 0.9607843160629272
# Image Augmented_2_resized_pa36.JPG: Min = 0.10196078568696976, Max = 1.0
# Image Augmented_4_resized_p19.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa68.JPG: Min = 0.2823529541492462, Max = 0.8352941274642944
# Image Augmented_3_resized_p35.JPG: Min = 0.0, Max = 0.5607843399047852
# Image Augmented_4_resized_p25.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f50.JPG: Min = 0.054901961237192154, Max = 0.9411764740943909
# Image Augmented_3_resized_pa40.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa54.JPG: Min = 0.0, Max = 0.9372549057006836
# Image Augmented_4_resized_p31.JPG: Min = 0.05882352963089943, Max = 0.8980392217636108
# Image Augmented_1_resized_f44.JPG: Min = 0.027450980618596077, Max = 1.0
# Image Augmented_3_resized_pa55.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f45.JPG: Min = 0.20392157137393951, Max = 0.7058823704719543
# Image Augmented_4_resized_p30.jpg: Min = 0.0117647061124444, Max = 1.0
# Image Augmented_1_resized_f51.JPG: Min = 0.1568627506494522, Max = 0.95686274766922
# Image Augmented_4_resized_p24.JPG: Min = 0.38823530077934265, Max = 0.9764705896377563
# Image Augmented_3_resized_pa41.jpg: Min = 0.0, Max = 0.6705882549285889
# Image Augmented_3_resized_pa69.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p34.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_p18.jpg: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_3_resized_n44.JPG: Min = 0.0, Max = 0.843137264251709
# Image Augmented_4_resized_fu18.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa37.jpg: Min = 0.3019607961177826, Max = 0.9843137264251709
# Image Augmented_2_resized_pa23.JPG: Min = 0.0, Max = 0.9803921580314636
# Image Augmented_3_resized_n50.JPG: Min = 0.0, Max = 0.9058823585510254
# Image Augmented_4_resized_n68.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_f1.JPG: Min = 0.0, Max = 0.8666666746139526
# Image Augmented_4_resized_n54.JPG: Min = 0.40784314274787903, Max = 0.95686274766922
# Image Augmented_4_resized_fu30.JPG: Min = 0.4470588266849518, Max = 0.9529411792755127
# Image Augmented_3_resized_f2.JPG: Min = 0.05098039284348488, Max = 0.8117647171020508
# Image Augmented_0_resized_p65.JPG: Min = 0.12941177189350128, Max = 0.9372549057006836
# Image Augmented_2_resized_f28.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa29.jpg: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_f14.JPG: Min = 0.0, Max = 0.686274528503418
# Image Augmented_0_resized_pa63.JPG: Min = 0.10588235408067703, Max = 0.686274528503418
# Image Augmented_0_resized_n29.JPG: Min = 0.0, Max = 0.8235294222831726
# Image Augmented_0_resized_n15.JPG: Min = 0.0, Max = 0.9843137264251709
# Image Augmented_0_resized_f34.JPG: Min = 0.125490203499794, Max = 0.8156862854957581
# Image Augmented_1_resized_fu56.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p51.JPG: Min = 0.2235294133424759, Max = 0.9215686321258545
# Image Augmented_2_resized_n35.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_3_resized_fu3.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p14.jfif: Min = 0.0, Max = 0.95686274766922
# Image Augmented_2_resized_n21.JPG: Min = 0.0, Max = 0.9725490212440491
# Image Augmented_4_resized_fu7.JPG: Min = 0.1411764770746231, Max = 0.8745098114013672
# Image Augmented_0_resized_fu20.JPG: Min = 0.0, Max = 0.9058823585510254
# Image Augmented_4_resized_f61.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_4_resized_f49.JPG: Min = 0.2705882489681244, Max = 1.0
# Image Augmented_2_resized_f6.JPG: Min = 0.0, Max = 0.6509804129600525
# Image Augmented_4_resized_pa67.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_2_resized_fu48.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_n58.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_n70.JPG: Min = 0.0, Max = 0.9725490212440491
# Image Augmented_2_resized_fu60.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_1_resized_n64.JPG: Min = 0.4156862795352936, Max = 0.8039215803146362
# Image Augmented_0_resized_fu9.JPG: Min = 0.0, Max = 0.8196078538894653
# Image Augmented_4_resized_pa14.JPG: Min = 0.0, Max = 0.7960784435272217
# Image Augmented_4_resized_pa28.JPG: Min = 0.0, Max = 0.9803921580314636
# Image Augmented_1_resized_n17.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu59.JPG: Min = 0.16078431904315948, Max = 1.0
# Image Augmented_1_resized_p67.JPG: Min = 0.21176470816135406, Max = 1.0
# Image Augmented_4_resized_f12.JPG: Min = 0.03921568766236305, Max = 0.8196078538894653
# Image Augmented_3_resized_fu65.JPG: Min = 0.0470588244497776, Max = 0.658823549747467
# Image Augmented_3_resized_f16.JPG: Min = 0.0, Max = 0.9882352948188782
# Image Augmented_2_resized_n46.JPG: Min = 0.10588235408067703, Max = 0.8980392217636108
# Image Augmented_2_resized_n52.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu47.JPG: Min = 0.05882352963089943, Max = 0.8509804010391235
# Image Augmented_0_resized_fu53.JPG: Min = 0.0, Max = 0.9843137264251709
# Image Augmented_1_resized_fu19.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_2_resized_p36.JPG: Min = 0.0, Max = 0.8313725590705872
# Image Augmented_1_resized_fu25.JPG: Min = 0.0, Max = 0.8470588326454163
# Image Augmented_1_resized_fu31.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_pa10.JPG: Min = 0.13333334028720856, Max = 1.0
# Image Augmented_0_resized_pa38.jpg: Min = 0.0784313753247261, Max = 0.7254902124404907
# Image Augmented_0_resized_n66.JPG: Min = 0.29019609093666077, Max = 0.8941176533699036
# Image Augmented_1_resized_pa66.JPG: Min = 0.3137255012989044, Max = 0.8039215803146362
# Image Augmented_2_resized_f67.JPG: Min = 0.0, Max = 0.8078431487083435
# Image Augmented_2_resized_fu1.jpg: Min = 0.0117647061124444, Max = 0.9764705896377563
# Image Augmented_2_resized_pa44.JPG: Min = 0.30980393290519714, Max = 0.8627451062202454
# Image Augmented_3_resized_n23.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f7.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_4_resized_n33.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_4_resized_fu57.JPG: Min = 0.0, Max = 0.8470588326454163
# Image Augmented_4_resized_n27.JPG: Min = 0.0, Max = 0.686274528503418
# Image Augmented_1_resized_f36.JPG: Min = 0.007843137718737125, Max = 1.0
# Image Augmented_3_resized_pa26.JPG: Min = 0.0, Max = 0.8666666746139526
# Image Augmented_4_resized_pa8.JPG: Min = 0.7372549176216125, Max = 1.0
# Image Augmented_4_resized_p57.JPG: Min = 0.0, Max = 0.7490196228027344
# Image Augmented_1_resized_f22.JPG: Min = 0.0, Max = 0.7490196228027344
# Image Augmented_3_resized_p47.JPG: Min = 0.3529411852359772, Max = 0.9843137264251709
# Image Augmented_3_resized_p53.JPG: Min = 0.0, Max = 0.9058823585510254
# Image Augmented_3_resized_p46.jpg: Min = 0.27450981736183167, Max = 0.9803921580314636
# Image Augmented_1_resized_f23.JPG: Min = 0.19607843458652496, Max = 1.0
# Image Augmented_4_resized_p56.JPG: Min = 0.05098039284348488, Max = 0.6745098233222961
# Image Augmented_4_resized_p42.JPG: Min = 0.0, Max = 0.9215686321258545
# Image Augmented_3_resized_pa27.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n26.JPG: Min = 0.0, Max = 0.7764706015586853
# Image Augmented_4_resized_fu56.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n32.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa51.JPG: Min = 0.0, Max = 0.9960784316062927
# Image Augmented_0_resized_f6.JPG: Min = 0.0, Max = 0.7411764860153198
# Image Augmented_2_resized_pa45.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_n36.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p17.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa67.JPG: Min = 0.0, Max = 0.7490196228027344
# Image Augmented_1_resized_fu30.JPG: Min = 0.14901961386203766, Max = 1.0
# Image Augmented_2_resized_p23.jpg: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p37.JPG: Min = 0.0, Max = 0.9098039269447327
# Image Augmented_0_resized_f46.JPG: Min = 0.0784313753247261, Max = 0.6431372761726379
# Image Augmented_1_resized_fu18.JPG: Min = 0.32156863808631897, Max = 1.0
# Image Augmented_0_resized_fu52.JPG: Min = 0.0, Max = 0.9529411792755127
# Image Augmented_0_resized_fu46.JPG: Min = 0.0, Max = 0.8549019694328308
# Image Augmented_1_resized_f2.JPG: Min = 0.0, Max = 0.9882352948188782
# Image Augmented_2_resized_n53.JPG: Min = 0.4156862795352936, Max = 1.0
# Image Augmented_2_resized_n47.JPG: Min = 0.18039216101169586, Max = 1.0
# Image Augmented_3_resized_f17.JPG: Min = 0.16078431904315948, Max = 1.0
# Image Augmented_1_resized_pa5.jpg: Min = 0.0, Max = 0.8549019694328308
# Image Augmented_3_resized_fu64.JPG: Min = 0.239215686917305, Max = 0.9529411792755127
# Image Augmented_1_resized_p66.JPG: Min = 0.20392157137393951, Max = 0.9137254953384399
# Image Augmented_1_resized_n16.JPG: Min = 0.35686275362968445, Max = 0.8941176533699036
# Image Augmented_2_resized_fu12.JPG: Min = 0.0, Max = 0.7843137383460999
# Image Augmented_4_resized_pa29.jpg: Min = 0.0, Max = 0.7490196228027344
# Image Augmented_0_resized_fu8.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n9.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_1_resized_n28.JPG: Min = 0.33725491166114807, Max = 0.9098039269447327
# Image Augmented_2_resized_fu38.JPG: Min = 0.0, Max = 0.8078431487083435
# Image Augmented_2_resized_fu10.JPG: Min = 0.16470588743686676, Max = 0.8313725590705872
# Image Augmented_1_resized_n14.JPG: Min = 0.06666667014360428, Max = 1.0
# Image Augmented_1_resized_p64.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_4_resized_f11.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f29.JPG: Min = 0.08235294371843338, Max = 1.0
# Image Augmented_1_resized_p70.JPG: Min = 0.0, Max = 0.9215686321258545
# Image Augmented_3_resized_fu66.JPG: Min = 0.3607843220233917, Max = 1.0
# Image Augmented_1_resized_pa7.JPG: Min = 0.0, Max = 0.9254902005195618
# Image Augmented_4_resized_f39.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p13.jfif: Min = 0.5176470875740051, Max = 0.9960784316062927
# Image Augmented_4_resized_p7.jfif: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu50.JPG: Min = 0.21176470816135406, Max = 1.0
# Image Augmented_0_resized_fu44.JPG: Min = 0.0, Max = 0.8823529481887817
# Image Augmented_0_resized_f50.JPG: Min = 0.0, Max = 0.7607843279838562
# Image Augmented_0_resized_f44.JPG: Min = 0.05882352963089943, Max = 1.0
# Image Augmented_2_resized_p35.JPG: Min = 0.01568627543747425, Max = 0.7843137383460999
# Image Augmented_0_resized_n59.JPG: Min = 0.007843137718737125, Max = 0.9215686321258545
# Image Augmented_0_resized_n65.JPG: Min = 0.0, Max = 0.8509804010391235
# Image Augmented_0_resized_p15.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p29.jpg: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_f64.JPG: Min = 0.0, Max = 0.8705882430076599
# Image Augmented_1_resized_pa59.JPG: Min = 0.0, Max = 0.8156862854957581
# Image Augmented_2_resized_f70.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f4.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa53.jpg: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n18.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_3_resized_n20.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_n34.JPG: Min = 0.12941177189350128, Max = 1.0
# Image Augmented_4_resized_fu68.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_2_resized_fu2.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa47.JPG: Min = 0.5372549295425415, Max = 1.0
# Image Augmented_1_resized_f21.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa31.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_3_resized_pa25.jpg: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f35.JPG: Min = 0.14509804546833038, Max = 0.8392156958580017
# Image Augmented_4_resized_p68.JPG: Min = 0.0, Max = 0.8196078538894653
# Image Augmented_3_resized_p50.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa19.JPG: Min = 0.0, Max = 0.8666666746139526
# Image Augmented_3_resized_p44.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa18.JPG: Min = 0.30980393290519714, Max = 1.0
# Image Augmented_3_resized_p51.JPG: Min = 0.19607843458652496, Max = 0.8901960849761963
# Image Augmented_4_resized_p69.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa24.JPG: Min = 0.1568627506494522, Max = 1.0
# Image Augmented_1_resized_f34.JPG: Min = 0.062745101749897, Max = 0.8941176533699036
# Image Augmented_4_resized_p55.JPG: Min = 0.03921568766236305, Max = 0.8470588326454163
# Image Augmented_3_resized_pa30.JPG: Min = 0.364705890417099, Max = 0.9058823585510254
# Image Augmented_4_resized_fu55.JPG: Min = 0.0, Max = 0.9882352948188782
# Image Augmented_4_resized_n31.JPG: Min = 0.0, Max = 0.7960784435272217
# Image Augmented_4_resized_n25.JPG: Min = 0.0, Max = 0.7764706015586853
# Image Augmented_4_resized_fu69.JPG: Min = 0.42352941632270813, Max = 1.0
# Image Augmented_3_resized_n35.JPG: Min = 0.0117647061124444, Max = 0.8156862854957581
# Image Augmented_2_resized_pa46.JPG: Min = 0.0, Max = 0.9529411792755127
# Image Augmented_2_resized_fu3.JPG: Min = 0.11372549086809158, Max = 1.0
# Image Augmented_0_resized_f5.JPG: Min = 0.11764705926179886, Max = 1.0
# Image Augmented_3_resized_n21.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n19.JPG: Min = 0.3764705955982208, Max = 1.0
# Image Augmented_1_resized_pa58.JPG: Min = 0.22745098173618317, Max = 0.7686274647712708
# Image Augmented_1_resized_pa64.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa70.JPG: Min = 0.4274509847164154, Max = 1.0
# Image Augmented_0_resized_n70.JPG: Min = 0.0, Max = 0.9647058844566345
# Image Augmented_0_resized_n64.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_0_resized_pa12.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_n58.JPG: Min = 0.0, Max = 0.8666666746139526
# Image Augmented_1_resized_fu27.JPG: Min = 0.0, Max = 0.8078431487083435
# Image Augmented_2_resized_p34.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu33.JPG: Min = 0.0, Max = 0.8509804010391235
# Image Augmented_0_resized_f45.JPG: Min = 0.11372549086809158, Max = 0.8196078538894653
# Image Augmented_0_resized_f51.JPG: Min = 0.0, Max = 0.9764705896377563
# Image Augmented_1_resized_f1.JPG: Min = 0.0, Max = 0.8980392217636108
# Image Augmented_0_resized_fu45.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu51.JPG: Min = 0.18431372940540314, Max = 1.0
# Image Augmented_2_resized_n44.JPG: Min = 0.007843137718737125, Max = 0.7333333492279053
# Image Augmented_2_resized_n50.JPG: Min = 0.0, Max = 0.9215686321258545
# Image Augmented_3_resized_fu67.JPG: Min = 0.0, Max = 0.9215686321258545
# Image Augmented_4_resized_f38.JPG: Min = 0.0, Max = 0.9254902005195618
# Image Augmented_3_resized_f14.JPG: Min = 0.0, Max = 0.9725490212440491
# Image Augmented_3_resized_f28.JPG: Min = 0.10980392247438431, Max = 1.0
# Image Augmented_1_resized_p65.JPG: Min = 0.0, Max = 0.9137254953384399
# Image Augmented_2_resized_fu11.JPG: Min = 0.0117647061124444, Max = 0.8980392217636108
# Image Augmented_1_resized_n15.JPG: Min = 0.0, Max = 0.9764705896377563
# Image Augmented_4_resized_pa16.JPG: Min = 0.0, Max = 0.7176470756530762
# Image Augmented_2_resized_n8.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_n29.JPG: Min = 0.0, Max = 0.7921568751335144
# Image Augmented_1_resized_n11.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_2_resized_fu15.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_fu29.JPG: Min = 0.0, Max = 0.7921568751335144
# Image Augmented_4_resized_pa12.JPG: Min = 0.4000000059604645, Max = 1.0
# Image Augmented_4_resized_f28.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa2.JPG: Min = 0.0, Max = 0.9921568632125854
# Image Augmented_3_resized_fu63.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_p61.JPG: Min = 0.1921568661928177, Max = 1.0
# Image Augmented_4_resized_f14.JPG: Min = 0.0, Max = 0.9725490212440491
# Image Augmented_3_resized_f38.JPG: Min = 0.06666667014360428, Max = 1.0
# Image Augmented_1_resized_p49.png: Min = 0.1725490242242813, Max = 1.0
# Image Augmented_2_resized_n68.JPG: Min = 0.0, Max = 0.8196078538894653
# Image Augmented_0_resized_fu55.JPG: Min = 0.019607843831181526, Max = 0.9450980424880981
# Image Augmented_1_resized_f5.JPG: Min = 0.0, Max = 0.9647058844566345
# Image Augmented_2_resized_n54.JPG: Min = 0.45490196347236633, Max = 1.0
# Image Augmented_0_resized_fu69.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p24.JPG: Min = 0.08627451211214066, Max = 1.0
# Image Augmented_0_resized_f69.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p30.jpg: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu23.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_2_resized_p18.jpg: Min = 0.20000000298023224, Max = 0.9529411792755127
# Image Augmented_0_resized_f41.JPG: Min = 0.10196078568696976, Max = 0.7019608020782471
# Image Augmented_0_resized_n60.JPG: Min = 0.13725490868091583, Max = 0.6705882549285889
# Image Augmented_3_resized_n8.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_0_resized_pa16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_n48.JPG: Min = 0.0, Max = 0.6627451181411743
# Image Augmented_1_resized_pa48.JPG: Min = 0.0, Max = 0.772549033164978
# Image Augmented_2_resized_f61.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p38.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_f49.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa60.JPG: Min = 0.20392157137393951, Max = 0.8352941274642944
# Image Augmented_4_resized_fu45.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_n19.JPG: Min = 0.33725491166114807, Max = 0.843137264251709
# Image Augmented_4_resized_n21.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n35.JPG: Min = 0.0, Max = 0.8039215803146362
# Image Augmented_4_resized_fu51.JPG: Min = 0.18431372940540314, Max = 0.8274509906768799
# Image Augmented_3_resized_n25.JPG: Min = 0.0, Max = 0.7372549176216125
# Image Augmented_2_resized_pa56.JPG: Min = 0.007843137718737125, Max = 0.8901960849761963
# Image Augmented_0_resized_f1.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_2_resized_fu7.JPG: Min = 0.01568627543747425, Max = 1.0
# Image Augmented_2_resized_pa42.JPG: Min = 0.12156862765550613, Max = 0.8392156958580017
# Image Augmented_3_resized_n31.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f18.JPG: Min = 0.0, Max = 0.7137255072593689
# Image Augmented_3_resized_p55.JPG: Min = 0.0, Max = 0.9058823585510254
# Image Augmented_3_resized_pa34.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p69.jpg: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_p51.JPG: Min = 0.2980392277240753, Max = 1.0
# Image Augmented_1_resized_f24.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f30.JPG: Min = 0.0, Max = 0.7921568751335144
# Image Augmented_3_resized_pa20.JPG: Min = 0.0, Max = 0.9803921580314636
# Image Augmented_4_resized_p44.JPG: Min = 0.0117647061124444, Max = 1.0
# Image Augmented_3_resized_pa21.JPG: Min = 0.3137255012989044, Max = 0.8549019694328308
# Image Augmented_3_resized_pa35.jpg: Min = 0.0313725508749485, Max = 0.8549019694328308
# Image Augmented_4_resized_p50.jpg: Min = 0.1568627506494522, Max = 1.0
# Image Augmented_3_resized_p68.JPG: Min = 0.0, Max = 0.8196078538894653
# Image Augmented_1_resized_f19.JPG: Min = 0.0, Max = 0.843137264251709
# Image Augmented_2_resized_fu6.JPG: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_2_resized_pa57.JPG: Min = 0.3176470696926117, Max = 0.9176470637321472
# Image Augmented_4_resized_fu50.JPG: Min = 0.1411764770746231, Max = 0.9764705896377563
# Image Augmented_4_resized_n34.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n20.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_n18.JPG: Min = 0.0, Max = 0.6549019813537598
# Image Augmented_4_resized_fu44.JPG: Min = 0.22745098173618317, Max = 0.8196078538894653
# Image Augmented_2_resized_f48.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_0_resized_p11.jpg: Min = 0.364705890417099, Max = 0.8549019694328308
# Image Augmented_2_resized_f60.JPG: Min = 0.0, Max = 0.8784313797950745
# Image Augmented_3_resized_n9.JPG: Min = 0.48235294222831726, Max = 0.9921568632125854
# Image Augmented_0_resized_n61.JPG: Min = 0.2823529541492462, Max = 0.8392156958580017
# Image Augmented_0_resized_f40.JPG: Min = 0.13725490868091583, Max = 1.0
# Image Augmented_2_resized_p19.jpg: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f54.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p31.JPG: Min = 0.0, Max = 0.929411768913269
# Image Augmented_1_resized_fu22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f68.JPG: Min = 0.12156862765550613, Max = 0.7607843279838562
# Image Augmented_2_resized_p25.JPG: Min = 0.13725490868091583, Max = 1.0
# Image Augmented_2_resized_n55.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu68.JPG: Min = 0.3803921639919281, Max = 0.8274509906768799
# Image Augmented_3_resized_p7.jfif: Min = 0.0941176488995552, Max = 0.9215686321258545
# Image Augmented_1_resized_f4.JPG: Min = 0.1764705926179886, Max = 0.9803921580314636
# Image Augmented_2_resized_n69.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f39.JPG: Min = 0.03921568766236305, Max = 0.8039215803146362
# Image Augmented_1_resized_p60.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_3_resized_fu62.JPG: Min = 0.0, Max = 0.9333333373069763
# Image Augmented_4_resized_f29.JPG: Min = 0.0, Max = 0.9647058844566345
# Image Augmented_3_resized_f11.JPG: Min = 0.0, Max = 0.9960784316062927
# Image Augmented_2_resized_p45.jfif: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_fu28.JPG: Min = 0.3450980484485626, Max = 0.8470588326454163
# Image Augmented_1_resized_n10.JPG: Min = 0.13725490868091583, Max = 0.9450980424880981
# Image Augmented_2_resized_fu14.JPG: Min = 0.0, Max = 0.8588235378265381
# Image Augmented_1_resized_n12.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa1.JPG: Min = 0.10588235408067703, Max = 0.8235294222831726
# Image Augmented_3_resized_fu60.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_1_resized_p62.JPG: Min = 0.09803921729326248, Max = 0.7647058963775635
# Image Augmented_4_resized_f17.JPG: Min = 0.26274511218070984, Max = 0.8588235378265381
# Image Augmented_3_resized_fu48.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f6.JPG: Min = 0.0, Max = 0.6980392336845398
# Image Augmented_0_resized_fu56.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu20.JPG: Min = 0.03529411926865578, Max = 0.9058823585510254
# Image Augmented_2_resized_p33.jpg: Min = 0.0, Max = 0.929411768913269
# Image Augmented_2_resized_p27.jpg: Min = 0.23137255012989044, Max = 1.0
# Image Augmented_3_resized_p14.jfif: Min = 0.0, Max = 0.8470588326454163
# Image Augmented_0_resized_f42.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_0_resized_f56.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_pa29.jpg: Min = 0.0, Max = 0.9254902005195618
# Image Augmented_0_resized_n63.JPG: Min = 0.0, Max = 0.8470588326454163
# Image Augmented_2_resized_f62.JPG: Min = 0.29019609093666077, Max = 1.0
# Image Augmented_1_resized_pa63.JPG: Min = 0.0, Max = 0.8980392217636108
# Image Augmented_4_resized_n36.JPG: Min = 0.0, Max = 0.9843137264251709
# Image Augmented_4_resized_fu52.JPG: Min = 0.0313725508749485, Max = 1.0
# Image Augmented_2_resized_pa69.jpg: Min = 0.0784313753247261, Max = 0.8549019694328308
# Image Augmented_4_resized_fu46.JPG: Min = 0.007843137718737125, Max = 0.7058823704719543
# Image Augmented_3_resized_n32.JPG: Min = 0.0, Max = 0.9411764740943909
# Image Augmented_2_resized_fu4.JPG: Min = 0.1411764770746231, Max = 1.0
# Image Augmented_2_resized_pa41.jpg: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_2_resized_pa55.JPG: Min = 0.4156862795352936, Max = 1.0
# Image Augmented_0_resized_f2.JPG: Min = 0.0235294122248888, Max = 0.6235294342041016
# Image Augmented_3_resized_n26.JPG: Min = 0.21568627655506134, Max = 0.6745098233222961
# Image Augmented_3_resized_p42.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p56.JPG: Min = 0.09019608050584793, Max = 0.800000011920929
# Image Augmented_3_resized_pa23.JPG: Min = 0.07450980693101883, Max = 1.0
# Image Augmented_4_resized_n8.JPG: Min = 0.2549019753932953, Max = 1.0
# Image Augmented_4_resized_p46.jpg: Min = 0.01568627543747425, Max = 0.8784313797950745
# Image Augmented_1_resized_f27.JPG: Min = 0.0, Max = 0.8941176533699036
# Image Augmented_3_resized_pa37.jpg: Min = 0.0, Max = 0.9607843160629272
# Image Augmented_1_resized_f26.JPG: Min = 0.0, Max = 0.9098039269447327
# Image Augmented_4_resized_p53.JPG: Min = 0.1764705926179886, Max = 0.8509804010391235
# Image Augmented_3_resized_pa36.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n9.JPG: Min = 0.3450980484485626, Max = 1.0
# Image Augmented_3_resized_pa22.JPG: Min = 0.24313725531101227, Max = 0.9019607901573181
# Image Augmented_1_resized_f32.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_p47.JPG: Min = 0.3450980484485626, Max = 0.8941176533699036
# Image Augmented_3_resized_p57.JPG: Min = 0.0, Max = 0.7921568751335144
# Image Augmented_3_resized_pa8.JPG: Min = 0.3686274588108063, Max = 1.0
# Image Augmented_2_resized_pa54.JPG: Min = 0.0, Max = 0.9098039269447327
# Image Augmented_3_resized_n27.JPG: Min = 0.12941177189350128, Max = 0.886274516582489
# Image Augmented_3_resized_n33.JPG: Min = 0.0, Max = 0.8039215803146362
# Image Augmented_2_resized_pa40.JPG: Min = 0.10196078568696976, Max = 0.8705882430076599
# Image Augmented_2_resized_fu5.JPG: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_2_resized_pa68.JPG: Min = 0.0, Max = 0.7568627595901489
# Image Augmented_4_resized_n23.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_fu47.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_4_resized_fu53.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p12.jpg: Min = 0.0, Max = 0.7529411911964417
# Image Augmented_2_resized_f63.JPG: Min = 0.38823530077934265, Max = 1.0
# Image Augmented_1_resized_p9.jfif: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_pa14.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_pa28.JPG: Min = 0.2666666805744171, Max = 0.9450980424880981
# Image Augmented_0_resized_n62.JPG: Min = 0.20000000298023224, Max = 1.0
# Image Augmented_0_resized_f57.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_0_resized_f43.JPG: Min = 0.0, Max = 0.7960784435272217
# Image Augmented_2_resized_p26.JPG: Min = 0.03529411926865578, Max = 0.772549033164978
# Image Augmented_1_resized_fu35.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu21.JPG: Min = 0.0, Max = 0.6313725709915161
# Image Augmented_2_resized_p32.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu57.JPG: Min = 0.18039216101169586, Max = 1.0
# Image Augmented_1_resized_f7.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_f16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_p63.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu49.JPG: Min = 0.23529411852359772, Max = 0.8941176533699036
# Image Augmented_3_resized_f12.JPG: Min = 0.0235294122248888, Max = 1.0
# Image Augmented_4_resized_pa10.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_pa38.jpg: Min = 0.0, Max = 0.9960784316062927
# Image Augmented_4_resized_pa35.jpg: Min = 0.14901961386203766, Max = 0.7411764860153198
# Image Augmented_4_resized_pa21.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n3.JPG: Min = 0.0, Max = 0.9215686321258545
# Image Augmented_1_resized_n36.JPG: Min = 0.01568627543747425, Max = 0.7450980544090271
# Image Augmented_4_resized_f27.JPG: Min = 0.0, Max = 0.9372549057006836
# Image Augmented_1_resized_p46.jpg: Min = 0.38823530077934265, Max = 0.929411768913269
# Image Augmented_1_resized_p13.jfif: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_3_resized_f23.JPG: Min = 0.3294117748737335, Max = 0.8627451062202454
# Image Augmented_3_resized_fu44.JPG: Min = 0.0, Max = 0.7137255072593689
# Image Augmented_3_resized_fu50.JPG: Min = 0.2705882489681244, Max = 0.8980392217636108
# Image Augmented_0_resized_fu66.JPG: Min = 0.26274511218070984, Max = 0.886274516582489
# Image Augmented_1_resized_fu38.JPG: Min = 0.14509804546833038, Max = 0.8117647171020508
# Image Augmented_2_resized_p17.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu10.JPG: Min = 0.06666667014360428, Max = 0.9843137264251709
# Image Augmented_0_resized_pa25.jpg: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_n7.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_0_resized_pa31.JPG: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_0_resized_pa19.JPG: Min = 0.3921568691730499, Max = 0.9490196108818054
# Image Augmented_0_resized_n53.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_n47.JPG: Min = 0.25882354378700256, Max = 0.8509804010391235
# Image Augmented_0_resized_p23.jpg: Min = 0.0, Max = 0.8980392217636108
# Image Augmented_1_resized_pa47.JPG: Min = 0.0, Max = 0.8627451062202454
# Image Augmented_0_resized_p3.JPG: Min = 0.0, Max = 0.8549019694328308
# Image Augmented_1_resized_pa53.jpg: Min = 0.0, Max = 0.8823529481887817
# Image Augmented_0_resized_p37.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_f46.JPG: Min = 0.0, Max = 0.48627451062202454
# Image Augmented_3_resized_n16.JPG: Min = 0.0, Max = 0.9960784316062927
# Image Augmented_2_resized_pa59.JPG: Min = 0.30980393290519714, Max = 0.7098039388656616
# Image Augmented_4_resized_n12.JPG: Min = 0.0, Max = 1.0
# ...
# Image Augmented_4_resized_pa49.JPG: Min = 0.0, Max = 0.8196078538894653
# Image Augmented_4_resized_pa65.JPG: Min = 0.0, Max = 0.8196078538894653
# Image Augmented_1_resized_p16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu36.JPG: Min = 0.0, Max = 0.6274510025978088
# Image Augmented_1_resized_fu54.JPG: Min = 0.0, Max = 0.9803921580314636
# Image Augmented_0_resized_pa49.JPG: Min = 0.29019609093666077, Max = 0.8352941274642944
# Image Augmented_0_resized_pa4.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_f3.JPG: Min = 0.09803921729326248, Max = 1.0
# Image Augmented_4_resized_fu32.JPG: Min = 0.0, Max = 0.7960784435272217
# Image Augmented_4_resized_n56.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p22.JPG: Min = 0.0, Max = 0.9058823585510254
# Image Augmented_1_resized_f53.JPG: Min = 0.0, Max = 0.8509804010391235
# Image Augmented_1_resized_f52.JPG: Min = 0.0, Max = 0.7686274647712708
# Image Augmented_4_resized_n57.JPG: Min = 0.13725490868091583, Max = 1.0
# Image Augmented_4_resized_n43.JPG: Min = 0.0, Max = 0.9803921580314636
# Image Augmented_0_resized_f37.JPG: Min = 0.21568627655506134, Max = 0.8549019694328308
# Image Augmented_2_resized_p52.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_2_resized_n22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f66.JPG: Min = 0.03529411926865578, Max = 0.729411780834198
# Image Augmented_2_resized_fu61.JPG: Min = 0.0, Max = 0.8980392217636108
# Image Augmented_3_resized_f58.JPG: Min = 0.05882352963089943, Max = 0.886274516582489
# Image Augmented_1_resized_fu43.JPG: Min = 0.003921568859368563, Max = 0.9254902005195618
# Image Augmented_0_resized_pa62.JPG: Min = 0.007843137718737125, Max = 0.729411780834198
# Image Augmented_2_resized_f15.JPG: Min = 0.0, Max = 0.8352941274642944
# Image Augmented_3_resized_f3.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n41.JPG: Min = 0.22745098173618317, Max = 1.0
# Image Augmented_3_resized_n51.JPG: Min = 0.4470588266849518, Max = 0.9764705896377563
# Image Augmented_4_resized_fu24.JPG: Min = 0.27843138575553894, Max = 0.886274516582489
# Image Augmented_0_resized_pa6.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_p59.JPG: Min = 0.0, Max = 0.8156862854957581
# Image Augmented_1_resized_fu42.JPG: Min = 0.01568627543747425, Max = 0.8901960849761963
# Image Augmented_3_resized_f59.JPG: Min = 0.0, Max = 0.8235294222831726
# Image Augmented_3_resized_fu16.JPG: Min = 0.16862745583057404, Max = 0.7960784435272217
# Image Augmented_1_resized_p28.jpg: Min = 0.054901961237192154, Max = 1.0
# Image Augmented_2_resized_fu13.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa4.JPG: Min = 0.0, Max = 0.772549033164978
# Image Augmented_1_resized_f3.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f53.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p22.JPG: Min = 0.21568627655506134, Max = 1.0
# Image Augmented_0_resized_p16.JPG: Min = 0.24705882370471954, Max = 0.8274509906768799
# Image Augmented_2_resized_pa50.jpg: Min = 0.0, Max = 0.9764705896377563
# Image Augmented_4_resized_fu43.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_p43.JPG: Min = 0.22745098173618317, Max = 0.8941176533699036
# Image Augmented_3_resized_p52.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f37.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_4_resized_fu42.JPG: Min = 0.45098039507865906, Max = 0.9372549057006836
# Image Augmented_3_resized_n22.JPG: Min = 0.0, Max = 0.8274509906768799
# Image Augmented_2_resized_f66.JPG: Min = 0.0, Max = 0.929411768913269
# Image Augmented_0_resized_pa39.JPG: Min = 0.0, Max = 0.7960784435272217
# Image Augmented_1_resized_fu24.JPG: Min = 0.3686274588108063, Max = 0.8588235378265381
# Image Augmented_0_resized_f52.JPG: Min = 0.0, Max = 0.9843137264251709
# Image Augmented_4_resized_f13.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f15.JPG: Min = 0.0235294122248888, Max = 0.572549045085907
# Image Augmented_2_resized_n51.JPG: Min = 0.0, Max = 0.8274509906768799
# Image Augmented_1_resized_fu32.JPG: Min = 0.0, Max = 0.9058823585510254
# Image Augmented_0_resized_pa13.JPG: Min = 0.0, Max = 0.8470588326454163
# Image Augmented_2_resized_f58.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa65.JPG: Min = 0.37254902720451355, Max = 0.8352941274642944
# Image Augmented_4_resized_n24.JPG: Min = 0.0, Max = 0.9137254953384399
# Image Augmented_4_resized_n30.JPG: Min = 0.0117647061124444, Max = 1.0
# Image Augmented_4_resized_fu54.JPG: Min = 0.0, Max = 0.9529411792755127
# Image Augmented_4_resized_p54.JPG: Min = 0.30980393290519714, Max = 0.8470588326454163
# Image Augmented_4_resized_p40.JPG: Min = 0.0, Max = 0.8549019694328308
# Image Augmented_2_resized_pa52.JPG: Min = 0.16862745583057404, Max = 0.7372549176216125
# Image Augmented_0_resized_p28.jpg: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_f59.JPG: Min = 0.0, Max = 0.8039215803146362
# Image Augmented_1_resized_pa6.JPG: Min = 0.0, Max = 0.8313725590705872
# Image Augmented_1_resized_p59.JPG: Min = 0.1568627506494522, Max = 1.0
# Image Augmented_2_resized_fu39.JPG: Min = 0.054901961237192154, Max = 0.8156862854957581
# Image Augmented_3_resized_p40.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p54.JPG: Min = 0.4470588266849518, Max = 0.9921568632125854
# Image Augmented_3_resized_n30.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_3_resized_n24.JPG: Min = 0.0, Max = 0.7529411911964417
# Image Augmented_0_resized_p39.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa49.JPG: Min = 0.0, Max = 0.9882352948188782
# Image Augmented_1_resized_fu36.JPG: Min = 0.0, Max = 0.7764706015586853
# Image Augmented_2_resized_n41.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu54.JPG: Min = 0.0, Max = 0.9019607901573181
# Image Augmented_4_resized_f15.JPG: Min = 0.019607843831181526, Max = 0.6352941393852234
# Image Augmented_1_resized_p48.JPG: Min = 0.27450981736183167, Max = 1.0
# Image Augmented_1_resized_pa3.JPG: Min = 0.23529411852359772, Max = 0.7882353067398071
# Image Augmented_4_resized_pa13.JPG: Min = 0.0117647061124444, Max = 0.6901960968971252
# Image Augmented_1_resized_n38.JPG: Min = 0.0, Max = 0.7882353067398071
# Image Augmented_2_resized_fu16.JPG: Min = 0.019607843831181526, Max = 1.0
# Image Augmented_4_resized_pa39.JPG: Min = 0.0, Max = 0.5607843399047852
# Image Augmented_3_resized_f13.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_fu42.JPG: Min = 0.4313725531101227, Max = 0.8313725590705872
# Image Augmented_2_resized_n43.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_n57.JPG: Min = 0.14901961386203766, Max = 0.9725490212440491
# Image Augmented_4_resized_n22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_p52.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p43.JPG: Min = 0.0, Max = 0.8980392217636108
# Image Augmented_0_resized_f3.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_pa62.JPG: Min = 0.1764705926179886, Max = 0.6941176652908325
# Image Augmented_2_resized_n56.JPG: Min = 0.0, Max = 0.7176470756530762
# Image Augmented_0_resized_fu43.JPG: Min = 0.0313725508749485, Max = 0.9372549057006836
# Image Augmented_3_resized_fu61.JPG: Min = 0.2666666805744171, Max = 1.0
# Image Augmented_1_resized_n22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_fu32.JPG: Min = 0.03529411926865578, Max = 0.7372549176216125
# Image Augmented_1_resized_p52.JPG: Min = 0.29411765933036804, Max = 1.0
# Image Augmented_3_resized_f37.JPG: Min = 0.0, Max = 0.8235294222831726
# Image Augmented_0_resized_f66.JPG: Min = 0.0, Max = 0.6941176652908325
# Image Augmented_2_resized_f52.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa65.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa13.JPG: Min = 0.0, Max = 0.7333333492279053
# Image Augmented_3_resized_pa4.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_2_resized_f53.JPG: Min = 0.125490203499794, Max = 0.9176470637321472
# Image Augmented_1_resized_pa52.JPG: Min = 0.20392157137393951, Max = 0.7764706015586853
# Image Augmented_0_resized_p22.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu39.JPG: Min = 0.08627451211214066, Max = 0.7843137383460999
# Image Augmented_2_resized_n2.JPG: Min = 0.0, Max = 0.6941176652908325
# Image Augmented_2_resized_p28.jpg: Min = 0.10196078568696976, Max = 1.0
# Image Augmented_1_resized_fu13.JPG: Min = 0.2862745225429535, Max = 1.0
# Image Augmented_0_resized_f59.JPG: Min = 0.0, Max = 0.6078431606292725
# Image Augmented_1_resized_pa50.jpg: Min = 0.0, Max = 0.9803921580314636
# Image Augmented_4_resized_fu61.JPG: Min = 0.09019608050584793, Max = 0.7764706015586853
# Image Augmented_3_resized_pa6.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_3_resized_p59.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_3_resized_pa39.JPG: Min = 0.0, Max = 0.7882353067398071
# Image Augmented_4_resized_p48.JPG: Min = 0.25882354378700256, Max = 1.0
# Image Augmented_4_resized_pa3.JPG: Min = 0.0235294122248888, Max = 0.9372549057006836
# Image Augmented_1_resized_f15.JPG: Min = 0.0, Max = 0.8313725590705872
# Image Augmented_4_resized_n38.JPG: Min = 0.0, Max = 0.8274509906768799
# Image Augmented_0_resized_n51.JPG: Min = 0.3450980484485626, Max = 0.7921568751335144
# Image Augmented_0_resized_f58.JPG: Min = 0.0, Max = 0.7490196228027344
# Image Augmented_1_resized_f8.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_fu24.JPG: Min = 0.0, Max = 0.9686274528503418
# Image Augmented_1_resized_n30.JPG: Min = 0.0313725508749485, Max = 1.0
# Image Augmented_1_resized_n24.JPG: Min = 0.0, Max = 0.9490196108818054
# Image Augmented_3_resized_fu42.JPG: Min = 0.250980406999588, Max = 0.8196078538894653
# Image Augmented_1_resized_p40.JPG: Min = 0.18039216101169586, Max = 0.8117647171020508
# Image Augmented_1_resized_p54.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p39.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_0_resized_n41.JPG: Min = 0.0, Max = 0.8078431487083435
# Image Augmented_3_resized_n38.JPG: Min = 0.3176470696926117, Max = 0.6039215922355652
# Image Augmented_0_resized_f8.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_n2.JPG: Min = 0.0, Max = 0.8313725590705872
# Image Augmented_3_resized_pa3.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p48.JPG: Min = 0.29411765933036804, Max = 1.0
# Image Augmented_4_resized_p59.JPG: Min = 0.2666666805744171, Max = 0.9803921580314636
# Image Augmented_4_resized_pa6.JPG: Min = 0.364705890417099, Max = 1.0
# Image Augmented_2_resized_pa62.JPG: Min = 0.20392157137393951, Max = 0.7372549176216125
# Image Augmented_0_resized_fu61.JPG: Min = 0.0, Max = 0.929411768913269
# Image Augmented_3_resized_fu43.JPG: Min = 0.07058823853731155, Max = 0.9529411792755127
# Image Augmented_1_resized_p43.JPG: Min = 0.16078431904315948, Max = 1.0
# Image Augmented_0_resized_n56.JPG: Min = 0.0, Max = 0.6509804129600525
# Image Augmented_3_resized_n2.JPG: Min = 0.0, Max = 0.7058823704719543
# Image Augmented_4_resized_pa4.JPG: Min = 0.23529411852359772, Max = 0.9333333373069763
# Image Augmented_1_resized_f13.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_pa49.JPG: Min = 0.29019609093666077, Max = 0.8509804010391235
# Image Augmented_0_resized_n43.JPG: Min = 0.21960784494876862, Max = 0.9450980424880981
# Image Augmented_0_resized_n57.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_f37.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu54.JPG: Min = 0.1764705926179886, Max = 0.9960784316062927
# Image Augmented_2_resized_fu36.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_1_resized_n41.JPG: Min = 0.25882354378700256, Max = 1.0
# Image Augmented_0_resized_fu39.JPG: Min = 0.0, Max = 0.7568627595901489
# Image Augmented_2_resized_n38.JPG: Min = 0.0, Max = 0.7843137383460999
# Image Augmented_2_resized_pa3.JPG: Min = 0.2235294133424759, Max = 0.800000011920929
# Image Augmented_2_resized_p48.JPG: Min = 0.1725490242242813, Max = 0.8980392217636108
# Image Augmented_1_resized_n2.JPG: Min = 0.16078431904315948, Max = 0.8274509906768799
# Image Augmented_0_resized_pa52.JPG: Min = 0.0, Max = 0.8274509906768799
# Image Augmented_0_resized_n30.JPG: Min = 0.0, Max = 0.8745098114013672
# Image Augmented_0_resized_n24.JPG: Min = 0.0, Max = 0.7607843279838562
# Image Augmented_0_resized_p40.JPG: Min = 0.10980392247438431, Max = 1.0
# Image Augmented_0_resized_p54.JPG: Min = 0.16078431904315948, Max = 0.8549019694328308
# Image Augmented_3_resized_p39.JPG: Min = 0.09803921729326248, Max = 0.8705882430076599
# Image Augmented_4_resized_p28.jpg: Min = 0.1921568661928177, Max = 1.0
# Image Augmented_3_resized_pa65.JPG: Min = 0.0, Max = 0.9372549057006836
# Image Augmented_2_resized_pa13.JPG: Min = 0.09803921729326248, Max = 0.9921568632125854
# Image Augmented_3_resized_fu32.JPG: Min = 0.027450980618596077, Max = 0.729411780834198
# Image Augmented_1_resized_n56.JPG: Min = 0.0, Max = 0.800000011920929
# Image Augmented_4_resized_f53.JPG: Min = 0.0117647061124444, Max = 0.7686274647712708
# Image Augmented_2_resized_f8.JPG: Min = 0.12941177189350128, Max = 0.7215686440467834
# Image Augmented_3_resized_fu24.JPG: Min = 0.364705890417099, Max = 0.7843137383460999
# Image Augmented_0_resized_p43.JPG: Min = 0.0, Max = 0.8941176533699036
# Image Augmented_2_resized_pa39.JPG: Min = 0.0, Max = 0.8392156958580017
# Image Augmented_4_resized_fu16.JPG: Min = 0.0, Max = 0.9647058844566345
# Image Augmented_4_resized_p16.JPG: Min = 0.0, Max = 0.8549019694328308
# Image Augmented_0_resized_pa50.jpg: Min = 0.25882354378700256, Max = 0.9843137264251709
# Image Augmented_0_resized_f13.JPG: Min = 0.0, Max = 0.8901960849761963
# Image Augmented_0_resized_fu13.JPG: Min = 0.0117647061124444, Max = 1.0
# Image Augmented_4_resized_f52.JPG: Min = 0.0235294122248888, Max = 0.8627451062202454
# Image Augmented_1_resized_n43.JPG: Min = 0.0235294122248888, Max = 0.8039215803146362
# Image Augmented_1_resized_n57.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_fu43.JPG: Min = 0.0, Max = 0.8941176533699036
# Image Augmented_4_resized_pa50.jpg: Min = 0.0, Max = 0.8274509906768799
# Image Augmented_3_resized_f52.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_fu61.JPG: Min = 0.0, Max = 0.8313725590705872
# Image Augmented_0_resized_n22.JPG: Min = 0.1882352977991104, Max = 0.8627451062202454
# Image Augmented_2_resized_f37.JPG: Min = 0.0, Max = 0.95686274766922
# Image Augmented_0_resized_p52.JPG: Min = 0.19607843458652496, Max = 1.0
# Image Augmented_4_resized_fu13.JPG: Min = 0.12156862765550613, Max = 1.0
# Image Augmented_1_resized_f66.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa62.JPG: Min = 0.29019609093666077, Max = 0.8705882430076599
# Image Augmented_3_resized_p16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_f8.JPG: Min = 0.08235294371843338, Max = 0.8549019694328308
# Image Augmented_2_resized_pa4.JPG: Min = 0.2549019753932953, Max = 1.0
# Image Augmented_0_resized_fu16.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_p22.JPG: Min = 0.27843138575553894, Max = 1.0
# Image Augmented_3_resized_f53.JPG: Min = 0.08235294371843338, Max = 0.7882353067398071
# Image Augmented_2_resized_fu42.JPG: Min = 0.0, Max = 0.7137255072593689
# Image Augmented_2_resized_fu54.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_fu36.JPG: Min = 0.0, Max = 0.7764706015586853
# Image Augmented_2_resized_pa6.JPG: Min = 0.0, Max = 1.0
# Image Augmented_2_resized_p59.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_pa49.JPG: Min = 0.0, Max = 1.0
# Image Augmented_1_resized_f59.JPG: Min = 0.0, Max = 1.0
# Image Augmented_3_resized_p28.jpg: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_n2.JPG: Min = 0.0, Max = 0.8549019694328308
# Image Augmented_1_resized_f58.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_p39.JPG: Min = 0.0, Max = 0.9960784316062927
# Image Augmented_4_resized_fu39.JPG: Min = 0.0, Max = 1.0
# Image Augmented_4_resized_f8.JPG: Min = 0.0, Max = 1.0
# Image Augmented_0_resized_f15.JPG: Min = 0.019607843831181526, Max = 0.8705882430076599
# Image Augmented_4_resized_pa52.JPG: Min = 0.0, Max = 0.8078431487083435
# Image Augmented_1_resized_n51.JPG: Min = 0.0, Max = 0.9137254953384399
# Normalization Completed For augmentation-validation.
# Normalization For All Images Completed.

# %%
# folder path
normalization_folder = 'normalization-images'

# function to count image files in a directory
def count_images_in_folder(folder_path):
    image_count = 0
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(('.jpg', '.JPG', '.png', '.jfif')):  # check for image files
                image_count += 1
    return image_count

# count images in normalization-train and normalization-validation subfolders
normalization_train_folder = os.path.join(normalization_folder, 'normalization-train')
normalization_validation_folder = os.path.join(normalization_folder, 'normalization-validation')

# count the images
train_image_count = count_images_in_folder(normalization_train_folder)
validation_image_count = count_images_in_folder(normalization_validation_folder)

# print the counts
print(f"Number Of Images In 'Normalization Train': {train_image_count}")
print(f"Number Of Images In 'Normalization Validation': {validation_image_count}")
print(f"Total Number Of Images In 'Normalization Images': {train_image_count + validation_image_count}")
# Out:
# Number Of Images In 'Normalization Train': 1300
# Number Of Images In 'Normalization Validation': 250
# Total Number Of Images In 'Normalization Images': 1550
